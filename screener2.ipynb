# %%
"""
DISCLAIMER: 

This software is provided solely for educational and research purposes. 
It is not intended to provide investment advice, and no investment recommendations are made herein. 
The developers are not financial advisors and accept no responsibility for any financial decisions or losses resulting from the use of this software. 
Always consult a professional financial advisor before making any investment decisions.
"""

import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from scipy.interpolate import interp1d

# --- Functions for Calculations ---

def yang_zhang(price_data, window=30, trading_periods=252):
    """
    Calculate realized volatility using the Yang–Zhang method.
    price_data must contain the columns: 'Open', 'High', 'Low', 'Close'
    """
    log_ho = np.log(price_data['High'] / price_data['Open'])
    log_lo = np.log(price_data['Low'] / price_data['Open'])
    log_co = np.log(price_data['Close'] / price_data['Open'])
    
    log_oc = np.log(price_data['Open'] / price_data['Close'].shift(1))
    log_oc_sq = log_oc ** 2
    
    log_cc = np.log(price_data['Close'] / price_data['Close'].shift(1))
    log_cc_sq = log_cc ** 2
    
    rs = log_ho * (log_ho - log_co) + log_lo * (log_lo - log_co)
    
    close_vol = log_cc_sq.rolling(window=window).sum() / (window - 1.0)
    open_vol  = log_oc_sq.rolling(window=window).sum() / (window - 1.0)
    window_rs = rs.rolling(window=window).sum() / (window - 1.0)
    
    k = 0.34 / (1.34 + ((window + 1) / (window - 1)))
    result = (open_vol + k * close_vol + (1 - k) * window_rs).apply(np.sqrt) * np.sqrt(trading_periods)
    return result.iloc[-1]

def build_term_structure(days, ivs):
    """
    Build a linear spline term structure from days-to-expiry and corresponding ATM IV values.
    Returns a function that interpolates IV for a given day.
    """
    days = np.array(days)
    ivs = np.array(ivs)
    sort_idx = days.argsort()
    days = days[sort_idx]
    ivs = ivs[sort_idx]
    spline = interp1d(days, ivs, kind='linear', fill_value="extrapolate")
    
    def term_spline(dte):
        if dte < days[0]:
            return ivs[0]
        elif dte > days[-1]:
            return ivs[-1]
        else:
            return float(spline(dte))
    return term_spline

# --- Helper Functions ---

def get_atm_iv_for_exp(stock, exp_str):
    """
    Retrieve the ATM implied volatility for a given expiration date.
    """
    try:
        chain = stock.option_chain(exp_str)
    except Exception:
        return None
    calls = chain.calls
    puts = chain.puts
    if calls.empty or puts.empty:
        return None
    underlying_price = get_current_price(stock)
    # Find the call and put with strike closest to the underlying price.
    calls['abs_diff'] = (calls['strike'] - underlying_price).abs()
    puts['abs_diff'] = (puts['strike'] - underlying_price).abs()
    call_idx = calls['abs_diff'].idxmin()
    put_idx = puts['abs_diff'].idxmin()
    call_iv = calls.loc[call_idx, 'impliedVolatility']
    put_iv = puts.loc[put_idx, 'impliedVolatility']
    atm_iv = (call_iv + put_iv) / 2.0
    return atm_iv

def get_sp500_tickers():
    """
    Scrape S&P 500 tickers from Wikipedia.
    """
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url)
    sp500_table = tables[0]
    tickers = sp500_table['Symbol'].tolist()
    tickers = [ticker.replace('.', '-') for ticker in tickers]
    return tickers

def get_current_price(stock):
    """
    Retrieve the current (latest available) closing price for the given yfinance ticker.
    """
    todays_data = stock.history(period='1d')
    if todays_data.empty:
        raise ValueError("No market price found.")
    return todays_data['Close'].iloc[0]

# --- Core Screening Function ---

def compute_metrics(ticker_symbol):
    """
    For a given ticker symbol, compute the following metrics:
      - avg_volume: whether the 30-day moving average volume is >= 1.5M shares.
      - iv30_rv30: whether the ratio of the 30-day ATM IV (closest to 30 days) to realized volatility (Yang-Zhang) is >= 1.25.
      - ts_slope: whether the term structure slope between the nearest expiring option and the nearest one expiring between 20-45 days is <= -0.00406.
      - expected_move: the straddle-based expected move (as a percentage string), computed from the near-term options chain.
    
    Returns a dictionary with boolean flags (pass/fail) for each metric plus the expected move.
    Returns None if data is incomplete.
    """
    try:
        ticker_symbol = ticker_symbol.strip().upper()
        if not ticker_symbol:
            return None
        
        stock = yf.Ticker(ticker_symbol)
        if len(stock.options) == 0:
            return None

        # Get all available expiration dates from yfinance (as date objects)
        all_exps = list(stock.options)
        if not all_exps:
            return None
        today = datetime.today().date()
        all_exps_dates = sorted(datetime.strptime(d, "%Y-%m-%d").date() for d in all_exps)
        
        # Select the nearest expiring option (first_expiry)
        first_expiry = all_exps_dates[0]
        first_exp_str = first_expiry.strftime("%Y-%m-%d")
        
        # Select the nearest option expiring between 20 and 45 days out.
        filtered_exps = [d for d in all_exps_dates if 20 <= (d - today).days <= 45]
        if filtered_exps:
            second_expiry = filtered_exps[0]
            second_exp_str = second_expiry.strftime("%Y-%m-%d")
        else:
            second_expiry = None
            second_exp_str = None
        
        # For the iv30/rv30 ratio, pick the expiration closest to 30 days.
        target30 = min(all_exps_dates, key=lambda d: abs((d - today).days - 30))
        target30_str = target30.strftime("%Y-%m-%d")
        
        # Get the ATM IV for each chosen expiration.
        iv_first = get_atm_iv_for_exp(stock, first_exp_str)
        iv_target30 = get_atm_iv_for_exp(stock, target30_str)
        if iv_first is None or iv_target30 is None:
            return None
        if second_expiry is not None:
            iv_second = get_atm_iv_for_exp(stock, second_exp_str)
        else:
            iv_second = None
        
        dte_first = (first_expiry - today).days
        dte_target30 = (target30 - today).days
        if second_expiry is not None:
            dte_second = (second_expiry - today).days
            ts_slope = (iv_second - iv_first) / (dte_second - dte_first)
        else:
            ts_slope = None  # Unable to compute slope without a second expiration
        
        # Calculate iv30/rv30 ratio using 3 months of price history.
        price_history = stock.history(period='3mo')
        if price_history.empty:
            return None
        rv30 = yang_zhang(price_history)
        if rv30 == 0:
            return None
        iv30_rv30 = iv_target30 / rv30
        
        # Compute the 30-day moving average volume.
        avg_volume = price_history['Volume'].rolling(window=30).mean().dropna().iloc[-1]
        
        # For expected move, use the near-term (first_expiry) options chain.
        try:
            chain_first = stock.option_chain(first_exp_str)
        except Exception:
            return None
        calls = chain_first.calls
        puts = chain_first.puts
        if calls.empty or puts.empty:
            return None
        calls['abs_diff'] = (calls['strike'] - get_current_price(stock)).abs()
        puts['abs_diff'] = (puts['strike'] - get_current_price(stock)).abs()
        call_idx = calls['abs_diff'].idxmin()
        put_idx = puts['abs_diff'].idxmin()
        call_bid = calls.loc[call_idx, 'bid']
        call_ask = calls.loc[call_idx, 'ask']
        put_bid = puts.loc[put_idx, 'bid']
        put_ask = puts.loc[put_idx, 'ask']
        if call_bid is not None and call_ask is not None:
            call_mid = (call_bid + call_ask) / 2.0
        else:
            call_mid = None
        if put_bid is not None and put_ask is not None:
            put_mid = (put_bid + put_ask) / 2.0
        else:
            put_mid = None
        if call_mid is None or put_mid is None:
            return None
        straddle = call_mid + put_mid
        underlying_price = get_current_price(stock)
        expected_move = f"{round(straddle / underlying_price * 100, 2)}%"
        
        return {
            'avg_volume': avg_volume >= 1500000,
            'iv30_rv30': iv30_rv30 >= 1.25,
            # If we couldn’t compute slope, mark it as failed.
            'ts_slope': ts_slope is not None and ts_slope <= -0.00406,
            'expected_move': expected_move,
            'raw': {
                'avg_volume': avg_volume,
                'iv30_rv30': iv30_rv30,
                'ts_slope': ts_slope if ts_slope is not None else 0,
                'iv_target30': iv_target30,
                'iv_first': iv_first,
                'iv_second': iv_second if iv_second is not None else 0,
                'dte_first': dte_first,
                'dte_second': (dte_second if second_expiry is not None else None),
                'dte_target30': dte_target30,
                'straddle': straddle,
                'underlying_price': underlying_price
            }
        }
    except Exception as e:
        # In production, you would log the error e.
        return None

def classify(metrics):
    """
    Classify a ticker based on its metrics.
      - Recommended: All three metrics pass.
      - Consider: Term slope passes and only one of the other two passes.
      - Avoid: Otherwise.
    """
    avg_volume_pass = metrics['avg_volume']
    iv30_rv30_pass  = metrics['iv30_rv30']
    ts_slope_pass   = metrics['ts_slope']
    
    if avg_volume_pass and iv30_rv30_pass and ts_slope_pass:
        return "Recommended"
    elif ts_slope_pass and ((avg_volume_pass and not iv30_rv30_pass) or (iv30_rv30_pass and not avg_volume_pass)):
        return "Consider"
    else:
        return "Avoid"

# --- Main Screening Script ---

def main():
    sp500_tickers = get_sp500_tickers()
    results = {}  # To hold classification and metrics for each ticker
    
    print("Screening S&P 500 companies based on all three metrics...\n")
    
    for ticker in sp500_tickers:
        print(f"Processing {ticker}...")
        metrics = compute_metrics(ticker)
        if metrics is None:
            print(f"  Data unavailable or incomplete for {ticker}. Skipping.\n")
            continue
        
        classification = classify(metrics)
        results[ticker] = {
            'classification': classification,
            'metrics': metrics
        }
        
        # Print the results for this ticker immediately:
        print(f"Ticker: {ticker}")
        print(f"  Classification: {classification}")
        print(f"  avg_volume >= 1.5M: {'PASS' if metrics['avg_volume'] else 'FAIL'} (30-day MA = {metrics['raw']['avg_volume']:.0f})")
        print(f"  iv30/rv30 >= 1.25: {'PASS' if metrics['iv30_rv30'] else 'FAIL'} (iv30/rv30 = {metrics['raw']['iv30_rv30']:.2f})")
        if metrics['raw']['dte_second'] is not None:
            print(f"  ts_slope (Nearest vs. 20-45 days): {'PASS' if metrics['ts_slope'] else 'FAIL'} (Slope = {metrics['raw']['ts_slope']:.5f})")
        else:
            print("  ts_slope: Unable to compute (no expiration found between 20-45 days)")
        print(f"  Expected Move: {metrics['expected_move']}\n")
    
    # Final summary:
    if not results:
        print("No tickers met the data requirements for screening.")
    else:
        print("\nFinal Screening Results:")
        for ticker, result in results.items():
            print(f"Ticker: {ticker}  ->  Classification: {result['classification']}")
    
if __name__ == "__main__":
    main()
# Out:
# Screening S&P 500 companies based on all three metrics...
#
# Processing MMM...
# Ticker: MMM
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4599210)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.95)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00051)
#   Expected Move: 3.43%
#
# Processing AOS...
# Ticker: AOS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1565120)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.12)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00229)
#   Expected Move: 2.91%
#
# Processing ABT...
# Ticker: ABT
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 7786040)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.96)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01107)
#   Expected Move: 4.39%
#
# Processing ABBV...
# Ticker: ABBV
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 8458377)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.87)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00282)
#   Expected Move: 3.24%
#
# Processing ACN...
# Ticker: ACN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4436763)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.75)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00370)
#   Expected Move: 2.56%
#
# Processing ADBE...
# Ticker: ADBE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4799683)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.66)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00266)
#   Expected Move: 3.13%
#
# Processing AMD...
# Ticker: AMD
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 41340407)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.83)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00496)
#   Expected Move: 5.86%
#
# Processing AES...
# Ticker: AES
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 14444163)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.03)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00241)
#   Expected Move: 5.96%
#
# Processing AFL...
# Ticker: AFL
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2225747)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.97)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01376)
#   Expected Move: 3.5%
#
# Processing A...
# Ticker: A
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2554323)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.93)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00375)
#   Expected Move: 3.87%
#
# Processing APD...
# Ticker: APD
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1291737)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.09)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00818)
#   Expected Move: 3.23%
#
# Processing ABNB...
# Ticker: ABNB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6029823)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.96)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00143)
#   Expected Move: 4.12%
#
# Processing AKAM...
# Ticker: AKAM
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2502730)
#   iv30/rv30 >= 1.25: PASS (iv30/rv30 = 1.32)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00279)
#   Expected Move: 3.81%
#
# Processing ALB...
# Ticker: ALB
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 3341793)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.93)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00502)
#   Expected Move: 6.07%
#
# Processing ARE...
# Ticker: ARE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1642383)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.96)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00180)
#   Expected Move: 3.73%
#
# Processing ALGN...
# Ticker: ALGN
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1403213)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.03)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01410)
#   Expected Move: 7.49%
#
# Processing ALLE...
# Ticker: ALLE
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1210587)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.23)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00161)
#   Expected Move: 3.74%
#
# Processing LNT...
# Ticker: LNT
#   Classification: Recommended
#   avg_volume >= 1.5M: PASS (30-day MA = 2226477)
#   iv30/rv30 >= 1.25: PASS (iv30/rv30 = 1.74)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00870)
#   Expected Move: 5.3%
#
# Processing ALL...
# Ticker: ALL
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2209090)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.90)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00628)
#   Expected Move: 2.3%
#
# Processing GOOGL...
# Ticker: GOOGL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 38920117)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.93)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00231)
#   Expected Move: 2.94%
#
# Processing GOOG...
# Ticker: GOOG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 25499543)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.95)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00204)
#   Expected Move: 2.94%
#
# Processing MO...
# Ticker: MO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 12751387)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.88)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00218)
#   Expected Move: 1.91%
#
# Processing AMZN...
# Ticker: AMZN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 57270267)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.75)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00072)
#   Expected Move: 3.79%
#
# Processing AMCR...
# Ticker: AMCR
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 34345790)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.06)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01960)
#   Expected Move: 5.24%
#
# Processing AEE...
# Ticker: AEE
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2149940)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.95)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01976)
#   Expected Move: 3.11%
#
# Processing AEP...
# Ticker: AEP
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 5317930)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.00)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00420)
#   Expected Move: 2.3%
#
# Processing AXP...
# Ticker: AXP
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4188683)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.75)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01258)
#   Expected Move: 5.22%
#
# Processing AIG...
# Ticker: AIG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6300600)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.92)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00227)
#   Expected Move: 2.48%
#
# Processing AMT...
# Ticker: AMT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3506347)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.86)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00029)
#   Expected Move: 2.15%
#
# Processing AWK...
# Ticker: AWK
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1886987)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.92)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00054)
#   Expected Move: 1.83%
#
# Processing AMP...
# Ticker: AMP
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 613113)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.84)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00430)
#   Expected Move: 3.29%
#
# Processing AME...
# Ticker: AME
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1606877)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.05)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00005)
#   Expected Move: 1.1%
#
# Processing AMGN...
# Ticker: AMGN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3348617)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.04)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00184)
#   Expected Move: 2.69%
#
# Processing APH...
# Ticker: APH
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 9327500)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.94)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00124)
#   Expected Move: 3.02%
#
# Processing ADI...
# Ticker: ADI
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4679087)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.76)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01541)
#   Expected Move: 6.22%
#
# Processing ANSS...
# Ticker: ANSS
#   Classification: Consider
#   avg_volume >= 1.5M: FAIL (30-day MA = 613440)
#   iv30/rv30 >= 1.25: PASS (iv30/rv30 = 1.52)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00685)
#   Expected Move: 3.77%
#
# Processing AON...
# Ticker: AON
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1418960)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.01)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00697)
#   Expected Move: 2.53%
#
# Processing APA...
# Ticker: APA
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 9620733)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.94)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00577)
#   Expected Move: 6.41%
#
# Processing APO...
# Ticker: APO
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 5418413)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.65)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00589)
#   Expected Move: 5.26%
#
# Processing AAPL...
# Ticker: AAPL
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 71531510)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.68)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00525)
#   Expected Move: 4.27%
#
# Processing AMAT...
# Ticker: AMAT
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 8743253)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.82)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01002)
#   Expected Move: 5.36%
#
# Processing APTV...
# Ticker: APTV
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4396033)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.00)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00518)
#   Expected Move: 5.34%
#
# Processing ACGL...
# Ticker: ACGL
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 1834380)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.05)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00615)
#   Expected Move: 3.74%
#
# Processing ADM...
# Ticker: ADM
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5768343)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.98)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00196)
#   Expected Move: 3.23%
#
# Processing ANET...
# Ticker: ANET
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 12276267)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.79)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00275)
#   Expected Move: 4.79%
#
# Processing AJG...
# Ticker: AJG
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 1708997)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.98)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00578)
#   Expected Move: 2.94%
#
# Processing AIZ...
# Ticker: AIZ
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 508910)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.15)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00544)
#   Expected Move: 4.83%
#
# Processing T...
# Ticker: T
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 48283347)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.83)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00085)
#   Expected Move: 2.35%
#
# Processing ATO...
# Ticker: ATO
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1036877)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.07)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00055)
#   Expected Move: 1.63%
#
# Processing ADSK...
# Ticker: ADSK
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 1908700)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.91)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00532)
#   Expected Move: 3.46%
#
# Processing ADP...
# Ticker: ADP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2283410)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.19)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00062)
#   Expected Move: 2.12%
#
# Processing AZO...
# Ticker: AZO
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 176630)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.81)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00300)
#   Expected Move: 2.17%
#
# Processing AVB...
# Ticker: AVB
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 914890)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.83)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01385)
#   Expected Move: 2.87%
#
# Processing AVY...
# Ticker: AVY
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 891743)
#   iv30/rv30 >= 1.25: PASS (iv30/rv30 = 1.32)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00010)
#   Expected Move: 2.8%
#
# Processing AXON...
# Ticker: AXON
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 782523)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.06)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00170)
#   Expected Move: 4.65%
#
# Processing BKR...
# Ticker: BKR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 9370557)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.87)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00290)
#   Expected Move: 4.23%
#
# Processing BALL...
# Ticker: BALL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2751270)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.13)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00367)
#   Expected Move: 3.48%
#
# Processing BAC...
# Ticker: BAC
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 58168990)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.67)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00978)
#   Expected Move: 4.66%
#
# Processing BAX...
# Ticker: BAX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4842467)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.11)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00282)
#   Expected Move: 4.23%
#
# Processing BDX...
# Ticker: BDX
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2297093)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.04)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00935)
#   Expected Move: 2.98%
#
# Processing BRK-B...
# Ticker: BRK-B
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6063630)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.69)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00167)
#   Expected Move: 2.1%
#
# Processing BBY...
# Ticker: BBY
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 5277823)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.63)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00769)
#   Expected Move: 5.38%
#
# Processing TECH...
# Ticker: TECH
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2225303)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.01)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.02127)
#   Expected Move: 11.13%
#
# Processing BIIB...
# Ticker: BIIB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1911123)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.23)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00326)
#   Expected Move: 2.73%
#
# Processing BLK...
# Ticker: BLK
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1097503)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.76)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00419)
#   Expected Move: 3.34%
#
# Processing BX...
# Ticker: BX
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 6450920)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.77)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01543)
#   Expected Move: 6.25%
#
# Processing BK...
# Ticker: BK
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4798820)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.88)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01212)
#   Expected Move: 3.1%
#
# Processing BA...
# Ticker: BA
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 10374657)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.77)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00486)
#   Expected Move: 4.55%
#
# Processing BKNG...
# Ticker: BKNG
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 325703)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.95)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00149)
#   Expected Move: 2.94%
#
# Processing BSX...
# Ticker: BSX
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 9771157)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.85)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00459)
#   Expected Move: 4.46%
#
# Processing BMY...
# Ticker: BMY
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 13625570)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.06)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00648)
#   Expected Move: 3.46%
#
# Processing AVGO...
# Ticker: AVGO
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 39404793)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.65)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00928)
#   Expected Move: 5.51%
#
# Processing BR...
# Ticker: BR
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 652840)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.02)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00133)
#   Expected Move: 2.26%
#
# Processing BRO...
# Ticker: BRO
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2030070)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.12)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00709)
#   Expected Move: 3.6%
#
# Processing BF-B...
# Ticker: BF-B
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 3752027)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.93)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01600)
#   Expected Move: 7.04%
#
# Processing BLDR...
# Ticker: BLDR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1777107)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.04)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00256)
#   Expected Move: 4.73%
#
# Processing BG...
# Ticker: BG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1970467)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.02)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00287)
#   Expected Move: 2.72%
#
# Processing BXP...
# Ticker: BXP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1671700)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.89)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00283)
#   Expected Move: 3.98%
#
# Processing CHRW...
# Ticker: CHRW
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 1622987)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.22)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00625)
#   Expected Move: 3.6%
#
# Processing CDNS...
# Ticker: CDNS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2463543)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.96)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00062)
#   Expected Move: 3.84%
#
# Processing CZR...
# Ticker: CZR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6644510)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.89)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00589)
#   Expected Move: 4.53%
#
# Processing CPT...
# Ticker: CPT
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1170363)
#   iv30/rv30 >= 1.25: PASS (iv30/rv30 = 1.38)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00237)
#   Expected Move: 4.18%
#
# Processing CPB...
# Ticker: CPB
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4087693)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.65)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00970)
#   Expected Move: 2.83%
#
# Processing COF...
# Ticker: COF
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5809693)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.73)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00360)
#   Expected Move: 4.61%
#
# Processing CAH...
# Ticker: CAH
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2775803)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.18)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00543)
#   Expected Move: 2.52%
#
# Processing KMX...
# Ticker: KMX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3823583)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.64)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00333)
#   Expected Move: 4.15%
#
# Processing CCL...
# Ticker: CCL
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 32012057)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.67)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00439)
#   Expected Move: 4.94%
#
# Processing CARR...
# Ticker: CARR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5445307)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.92)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00245)
#   Expected Move: 3.75%
#
# Processing CAT...
# Ticker: CAT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3267500)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.77)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00391)
#   Expected Move: 3.25%
#
# Processing CBOE...
# Ticker: CBOE
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1050837)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.93)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00646)
#   Expected Move: 2.51%
#
# Processing CBRE...
# Ticker: CBRE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2197153)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.92)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00262)
#   Expected Move: 3.49%
#
# Processing CDW...
# Ticker: CDW
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1747533)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.17)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00241)
#   Expected Move: 4.55%
#
# Processing COR...
# Ticker: COR
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2020710)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.98)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00438)
#   Expected Move: 2.43%
#
# Processing CNC...
# Ticker: CNC
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4623620)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.99)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00129)
#   Expected Move: 3.49%
#
# Processing CNP...
# Ticker: CNP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6443990)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.16)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00203)
#   Expected Move: 2.01%
#
# Processing CF...
# Ticker: CF
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 3017480)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.04)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00727)
#   Expected Move: 3.56%
#
# Processing CRL...
# Ticker: CRL
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 1819590)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.03)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00664)
#   Expected Move: 7.2%
#
# Processing SCHW...
# Ticker: SCHW
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 12337430)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.81)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01455)
#   Expected Move: 5.67%
#
# Processing CHTR...
# Ticker: CHTR
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1488720)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.13)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00167)
#   Expected Move: 3.5%
#
# Processing CVX...
# Ticker: CVX
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 11145537)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.89)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00413)
#   Expected Move: 3.28%
#
# Processing CMG...
# Ticker: CMG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 14666343)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.00)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00058)
#   Expected Move: 3.5%
#
# Processing CB...
# Ticker: CB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2072263)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.09)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00371)
#   Expected Move: 2.72%
#
# Processing CHD...
# Ticker: CHD
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1817187)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.16)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00080)
#   Expected Move: 2.06%
#
# Processing CI...
# Ticker: CI
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1830253)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.11)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00059)
#   Expected Move: 2.38%
#
# Processing CINF...
# Ticker: CINF
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 960593)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.07)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00816)
#   Expected Move: 3.34%
#
# Processing CTAS...
# Ticker: CTAS
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2297020)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.87)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00767)
#   Expected Move: 2.44%
#
# Processing CSCO...
# Ticker: CSCO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 26853960)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.05)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00160)
#   Expected Move: 2.67%
#
# Processing C...
# Ticker: C
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 21164387)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.72)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.01051)
#   Expected Move: 4.94%
#
# Processing CFG...
# Ticker: CFG
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 6068250)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.88)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00737)
#   Expected Move: 5.55%
#
# Processing CLX...
# Ticker: CLX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1597143)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.20)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00140)
#   Expected Move: 2.41%
#
# Processing CME...
# Ticker: CME
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 3240240)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.00)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00476)
#   Expected Move: 2.71%
#
# Processing CMS...
# Ticker: CMS
#   Classification: Recommended
#   avg_volume >= 1.5M: PASS (30-day MA = 2750717)
#   iv30/rv30 >= 1.25: PASS (iv30/rv30 = 1.39)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00721)
#   Expected Move: 4.56%
#
# Processing KO...
# Ticker: KO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 20794897)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.81)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00022)
#   Expected Move: 1.61%
#
# Processing CTSH...
# Ticker: CTSH
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4629057)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.03)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00573)
#   Expected Move: 3.92%
#
# Processing CL...
# Ticker: CL
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 5892297)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.88)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00945)
#   Expected Move: 2.55%
#
# Processing CMCSA...
# Ticker: CMCSA
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 29465567)
#   iv30/rv30 >= 1.25: PASS (iv30/rv30 = 1.29)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = 0.00003)
#   Expected Move: 2.34%
#
# Processing CAG...
# Ticker: CAG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6991450)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.74)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00387)
#   Expected Move: 2.39%
#
# Processing COP...
# Ticker: COP
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 11443497)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.90)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00469)
#   Expected Move: 4.57%
#
# Processing ED...
# Ticker: ED
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3233470)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.94)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00193)
#   Expected Move: 2.47%
#
# Processing STZ...
# Ticker: STZ
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2741443)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.73)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00273)
#   Expected Move: 2.31%
#
# Processing CEG...
# Ticker: CEG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4754413)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 0.77)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00023)
#   Expected Move: 5.08%
#
# Processing COO...
# Ticker: COO
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 2495163)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.17)
#   ts_slope (Nearest vs. 20-45 days): PASS (Slope = -0.00516)
#   Expected Move: 5.05%
#
# Processing CPRT...
# Ticker: CPRT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5663723)
#   iv30/rv30 >= 1.25: FAIL (iv30/rv30 = 1.23)
#   ts_slope (Nearest vs. 20-45 days): FAIL (Slope = -0.00064)
#   Expected Move: 2.21%
#
# Processing GLW...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 299
#     296             print(f"Ticker: {ticker}  ->  Classification: {result['classification']}")
#     298 if __name__ == "__main__":
# --> 299     main()
#
# Cell In[4], line 268, in main()
#     266 for ticker in sp500_tickers:
#     267     print(f"Processing {ticker}...")
# --> 268     metrics = compute_metrics(ticker)
#     269     if metrics is None:
#     270         print(f"  Data unavailable or incomplete for {ticker}. Skipping.\n")
#
# Cell In[4], line 157, in compute_metrics(ticker_symbol)
#     155 # Get the ATM IV for each chosen expiration.
#     156 iv_first = get_atm_iv_for_exp(stock, first_exp_str)
# --> 157 iv_target30 = get_atm_iv_for_exp(stock, target30_str)
#     158 if iv_first is None or iv_target30 is None:
#     159     return None
#
# Cell In[4], line 78, in get_atm_iv_for_exp(stock, exp_str)
#      76 if calls.empty or puts.empty:
#      77     return None
# ---> 78 underlying_price = get_current_price(stock)
#      79 # Find the call and put with strike closest to the underlying price.
#      80 calls['abs_diff'] = (calls['strike'] - underlying_price).abs()
#
# Cell In[4], line 104, in get_current_price(stock)
#     100 def get_current_price(stock):
#     101     """
#     102     Retrieve the current (latest available) closing price for the given yfinance ticker.
#     103     """
# --> 104     todays_data = stock.history(period='1d')
#     105     if todays_data.empty:
#     106         raise ValueError("No market price found.")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yfinance\base.py:82, in TickerBase.history(self, *args, **kwargs)
#      80 @utils.log_indent_decorator
#      81 def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 82     return self._lazy_load_price_history().history(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yfinance\scrapers\history.py:175, in PriceHistory.history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, repair, keepna, proxy, rounding, timeout, raise_errors)
#     173         get_fn = self._data.cache_get
#     174 try:
# --> 175     data = get_fn(
#     176         url=url,
#     177         params=params,
#     178         proxy=proxy,
#     179         timeout=timeout
#     180     )
#     181     if "Will be right back" in data.text or data is None:
#     182         raise RuntimeError("*** YAHOO! FINANCE IS CURRENTLY DOWN! ***\n"
#     183                            "Our engineers are working quickly to resolve "
#     184                            "the issue. Thank you for your patience.")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yfinance\data.py:349, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     347 @utils.log_indent_decorator
#     348 def get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 349     return self._make_request(url, request_method = self._session.get, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\yfinance\data.py:394, in YfData._make_request(self, url, request_method, user_agent_headers, body, params, proxy, timeout)
#     391 if body:
#     392     request_args['json'] = body
# --> 394 response = request_method(**request_args)
#     395 utils.get_yf_logger().debug(f'response code={response.status_code}')
#     396 if response.status_code >= 400:
#     397     # Retry with other cookie strategy
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:481, in Session.prepare_request(self, request)
#     479 auth = request.auth
#     480 if self.trust_env and not auth and not self.auth:
# --> 481     auth = get_netrc_auth(request.url)
#     483 p = PreparedRequest()
#     484 p.prepare(
#     485     method=request.method.upper(),
#     486     url=request.url,
#    (...)
#     496     hooks=merge_hooks(request.hooks, self.hooks),
#     497 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\utils.py:227, in get_netrc_auth(url, raise_errors)
#     221 except KeyError:
#     222     # os.path.expanduser can fail when $HOME is undefined and
#     223     # getpwuid fails. See https://bugs.python.org/issue20164 &
#     224     # https://github.com/psf/requests/issues/1846
#     225     return
# --> 227 if os.path.exists(loc):
#     228     netrc_path = loc
#     229     break
#
# KeyboardInterrupt:
