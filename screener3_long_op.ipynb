# %%
"""
DISCLAIMER: 

This software is provided solely for educational and research purposes. 
It is not intended to provide investment advice, and no investment recommendations are made herein. 
The developers are not financial advisors and accept no responsibility for any financial decisions or losses resulting from the use of this software. 
Always consult a professional financial advisor before making any investment decisions.
"""

import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from scipy.interpolate import interp1d

# --- Functions for Calculations ---

def yang_zhang(price_data, window=30, trading_periods=252):
    """
    Calculate realized volatility using the Yang–Zhang method.
    price_data must contain the columns: 'Open', 'High', 'Low', 'Close'
    """
    log_ho = np.log(price_data['High'] / price_data['Open'])
    log_lo = np.log(price_data['Low'] / price_data['Open'])
    log_co = np.log(price_data['Close'] / price_data['Open'])
    
    log_oc = np.log(price_data['Open'] / price_data['Close'].shift(1))
    log_oc_sq = log_oc ** 2
    
    log_cc = np.log(price_data['Close'] / price_data['Close'].shift(1))
    log_cc_sq = log_cc ** 2
    
    rs = log_ho * (log_ho - log_co) + log_lo * (log_lo - log_co)
    
    close_vol = log_cc_sq.rolling(window=window).sum() / (window - 1.0)
    open_vol  = log_oc_sq.rolling(window=window).sum() / (window - 1.0)
    window_rs = rs.rolling(window=window).sum() / (window - 1.0)
    
    k = 0.34 / (1.34 + ((window + 1) / (window - 1)))
    result = (open_vol + k * close_vol + (1 - k) * window_rs).apply(np.sqrt) * np.sqrt(trading_periods)
    return result.iloc[-1]

def build_term_structure(days, ivs):
    """
    Build a linear spline term structure from days-to-expiry and corresponding ATM IV values.
    Returns a function that interpolates IV for a given day.
    """
    days = np.array(days)
    ivs = np.array(ivs)
    sort_idx = days.argsort()
    days = days[sort_idx]
    ivs = ivs[sort_idx]
    spline = interp1d(days, ivs, kind='linear', fill_value="extrapolate")
    
    def term_spline(dte):
        if dte < days[0]:
            return ivs[0]
        elif dte > days[-1]:
            return ivs[-1]
        else:
            return float(spline(dte))
    return term_spline

# --- Helper Functions ---

def get_atm_iv_for_exp(stock, exp_str):
    """
    Retrieve the ATM implied volatility for a given expiration date.
    """
    try:
        chain = stock.option_chain(exp_str)
    except Exception:
        return None
    calls = chain.calls
    puts = chain.puts
    if calls.empty or puts.empty:
        return None
    underlying_price = get_current_price(stock)
    # Find the call and put with strike closest to the underlying price.
    calls['abs_diff'] = (calls['strike'] - underlying_price).abs()
    puts['abs_diff'] = (puts['strike'] - underlying_price).abs()
    call_idx = calls['abs_diff'].idxmin()
    put_idx = puts['abs_diff'].idxmin()
    call_iv = calls.loc[call_idx, 'impliedVolatility']
    put_iv = puts.loc[put_idx, 'impliedVolatility']
    atm_iv = (call_iv + put_iv) / 2.0
    return atm_iv

def get_sp500_tickers():
    """
    Scrape S&P 500 tickers from Wikipedia.
    """
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url)
    sp500_table = tables[0]
    tickers = sp500_table['Symbol'].tolist()
    tickers = [ticker.replace('.', '-') for ticker in tickers]
    return tickers

def get_current_price(stock):
    """
    Retrieve the current (latest available) closing price for the given yfinance ticker.
    """
    todays_data = stock.history(period='1d')
    if todays_data.empty:
        raise ValueError("No market price found.")
    return todays_data['Close'].iloc[0]

# --- Core Screening Function ---

def compute_metrics(ticker_symbol):
    """
    For a given ticker symbol, compute the following metrics:
      - avg_volume: whether the 30-day moving average volume is >= 1.5M shares.
      - iv30_rv30: whether the ratio of the 30-day ATM IV (closest to 30 days) to realized volatility (Yang-Zhang) is >= 1.25.
      - ts_slope: whether the term structure slope between the nearest expiring option and the nearest one expiring between 20-45 days is <= -0.00406.
      - expected_move: the straddle-based expected move (as a percentage string), computed from the near-term options chain.
    
    Returns a dictionary with boolean flags (pass/fail) for each metric plus the expected move.
    Returns None if data is incomplete.
    """
    try:
        ticker_symbol = ticker_symbol.strip().upper()
        if not ticker_symbol:
            return None
        
        stock = yf.Ticker(ticker_symbol)
        if len(stock.options) == 0:
            return None

        # Get all available expiration dates from yfinance (as date objects)
        all_exps = list(stock.options)
        if not all_exps:
            return None
        today = datetime.today().date()
        all_exps_dates = sorted(datetime.strptime(d, "%Y-%m-%d").date() for d in all_exps)
        
        # Select the nearest expiring option (first_expiry)
        first_expiry = all_exps_dates[0]
        first_exp_str = first_expiry.strftime("%Y-%m-%d")
        
        # Select the nearest option expiring between 4 and 20 days out.
        filtered_exps = [d for d in all_exps_dates if 4 <= (d - today).days <= 20]
        if filtered_exps:
            second_expiry = filtered_exps[0]
            second_exp_str = second_expiry.strftime("%Y-%m-%d")
        else:
            second_expiry = None
            second_exp_str = None
        
        # For the iv30/rv30 ratio, pick the expiration closest to 30 days.
        target30 = min(all_exps_dates, key=lambda d: abs((d - today).days - 30))
        target30_str = target30.strftime("%Y-%m-%d")
        
        # Get the ATM IV for each chosen expiration.
        iv_first = get_atm_iv_for_exp(stock, first_exp_str)
        iv_target30 = get_atm_iv_for_exp(stock, target30_str)
        if iv_first is None or iv_target30 is None:
            return None
        if second_expiry is not None:
            iv_second = get_atm_iv_for_exp(stock, second_exp_str)
        else:
            iv_second = None
        
        dte_first = (first_expiry - today).days
        dte_target30 = (target30 - today).days
        if second_expiry is not None:
            dte_second = (second_expiry - today).days
            ts_slope = (iv_second - iv_first) / (dte_second - dte_first)
        else:
            ts_slope = None  # Unable to compute slope without a second expiration
        
        # Calculate iv30/rv30 ratio using 3 months of price history.
        price_history = stock.history(period='3mo')
        if price_history.empty:
            return None
        rv30 = yang_zhang(price_history)
        if rv30 == 0:
            return None
        iv30_rv30 = iv_target30 / rv30
        
        # Compute the 30-day moving average volume.
        avg_volume = price_history['Volume'].rolling(window=30).mean().dropna().iloc[-1]
        
        # For expected move, use the near-term (first_expiry) options chain.
        try:
            chain_first = stock.option_chain(first_exp_str)
        except Exception:
            return None
        calls = chain_first.calls
        puts = chain_first.puts
        if calls.empty or puts.empty:
            return None
        calls['abs_diff'] = (calls['strike'] - get_current_price(stock)).abs()
        puts['abs_diff'] = (puts['strike'] - get_current_price(stock)).abs()
        call_idx = calls['abs_diff'].idxmin()
        put_idx = puts['abs_diff'].idxmin()
        call_bid = calls.loc[call_idx, 'bid']
        call_ask = calls.loc[call_idx, 'ask']
        put_bid = puts.loc[put_idx, 'bid']
        put_ask = puts.loc[put_idx, 'ask']
        if call_bid is not None and call_ask is not None:
            call_mid = (call_bid + call_ask) / 2.0
        else:
            call_mid = None
        if put_bid is not None and put_ask is not None:
            put_mid = (put_bid + put_ask) / 2.0
        else:
            put_mid = None
        if call_mid is None or put_mid is None:
            return None
        straddle = call_mid + put_mid
        underlying_price = get_current_price(stock)
        expected_move = f"{round(straddle / underlying_price * 100, 2)}%"
        
        return {
            'avg_volume': avg_volume >= 1500000,
            'iv30_rv30': iv30_rv30 <= 0.64,
            # If we couldn’t compute slope, mark it as failed.
            'ts_slope': ts_slope is not None and ts_slope >= 0.0025,
            'expected_move': expected_move,
            'raw': {
                'avg_volume': avg_volume,
                'iv30_rv30': iv30_rv30,
                'ts_slope': ts_slope if ts_slope is not None else 0,
                'iv_target30': iv_target30,
                'iv_first': iv_first,
                'iv_second': iv_second if iv_second is not None else 0,
                'dte_first': dte_first,
                'dte_second': (dte_second if second_expiry is not None else None),
                'dte_target30': dte_target30,
                'straddle': straddle,
                'underlying_price': underlying_price
            }
        }
    except Exception as e:
        # In production, you would log the error e.
        return None

def classify(metrics):
    """
    Classify a ticker based on its metrics.
      - Recommended: All three metrics pass.
      - Consider: Term slope passes and only one of the other two passes.
      - Avoid: Otherwise.
    """
    avg_volume_pass = metrics['avg_volume']
    iv30_rv30_pass  = metrics['iv30_rv30']
    ts_slope_pass   = metrics['ts_slope']
    
    if avg_volume_pass and iv30_rv30_pass and ts_slope_pass:
        return "Recommended"
    elif ts_slope_pass and ((avg_volume_pass and not iv30_rv30_pass) or (iv30_rv30_pass and not avg_volume_pass)):
        return "Consider"
    else:
        return "Avoid"

# --- Main Screening Script ---

def main():
    sp500_tickers = get_sp500_tickers()
    results = {}  # To hold classification and metrics for each ticker
    
    print("Screening S&P 500 companies based on all three metrics...\n")
    
    for ticker in sp500_tickers:
        print(f"Processing {ticker}...")
        metrics = compute_metrics(ticker)
        if metrics is None:
            print(f"  Data unavailable or incomplete for {ticker}. Skipping.\n")
            continue
        
        classification = classify(metrics)
        results[ticker] = {
            'classification': classification,
            'metrics': metrics
        }
        
        # Print the results for this ticker immediately:
        print(f"Ticker: {ticker}")
        print(f"  Classification: {classification}")
        print(f"  avg_volume >= 1.5M: {'PASS' if metrics['avg_volume'] else 'FAIL'} (30-day MA = {metrics['raw']['avg_volume']:.0f})")
        print(f"  iv30/rv30 <= 0.64: {'PASS' if metrics['iv30_rv30'] else 'FAIL'} (iv30/rv30 = {metrics['raw']['iv30_rv30']:.2f})")
        if metrics['raw']['dte_second'] is not None:
            print(f"  ts_slope (Nearest vs. 4-20 days): {'PASS' if metrics['ts_slope'] else 'FAIL'} (Slope = {metrics['raw']['ts_slope']:.5f})")
        else:
            print("  ts_slope: Unable to compute (no expiration found between 4-20 days)")
        print(f"  Expected Move: {metrics['expected_move']}\n")
    
    # Final summary:
    if not results:
        print("No tickers met the data requirements for screening.")
    else:
        print("\nFinal Screening Results:")
        for ticker, result in results.items():
            print(f"Ticker: {ticker}  ->  Classification: {result['classification']}")
    
if __name__ == "__main__":
    main()
# Out:
# Screening S&P 500 companies based on all three metrics...
#
# Processing MMM...
# Ticker: MMM
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4599210)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.95)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.01293)
#   Expected Move: 3.43%
#
# Processing AOS...
# Ticker: AOS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1565120)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.12)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.91%
#
# Processing ABT...
# Ticker: ABT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 7786040)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.96)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01941)
#   Expected Move: 4.39%
#
# Processing ABBV...
# Ticker: ABBV
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 8458377)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.87)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.00288)
#   Expected Move: 3.24%
#
# Processing ACN...
# Ticker: ACN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4436763)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.75)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00427)
#   Expected Move: 2.56%
#
# Processing ADBE...
# Ticker: ADBE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4799683)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.66)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01151)
#   Expected Move: 3.13%
#
# Processing AMD...
# Ticker: AMD
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 41340407)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.83)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02109)
#   Expected Move: 5.86%
#
# Processing AES...
# Ticker: AES
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 14444163)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.03)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.96%
#
# Processing AFL...
# Ticker: AFL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2225747)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.97)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.03101)
#   Expected Move: 3.5%
#
# Processing A...
# Ticker: A
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2554323)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.93)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.87%
#
# Processing APD...
# Ticker: APD
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1291737)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.09)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.23%
#
# Processing ABNB...
# Ticker: ABNB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6029823)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.96)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00900)
#   Expected Move: 4.12%
#
# Processing AKAM...
# Ticker: AKAM
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2502730)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.32)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00720)
#   Expected Move: 3.81%
#
# Processing ALB...
# Ticker: ALB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3341793)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.93)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01309)
#   Expected Move: 6.07%
#
# Processing ARE...
# Ticker: ARE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1642383)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.96)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.73%
#
# Processing ALGN...
# Ticker: ALGN
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1403213)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.03)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.05041)
#   Expected Move: 7.49%
#
# Processing ALLE...
# Ticker: ALLE
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1210587)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.23)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.74%
#
# Processing LNT...
# Ticker: LNT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2226477)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.74)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.3%
#
# Processing ALL...
# Ticker: ALL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2209090)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.90)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.3%
#
# Processing GOOGL...
# Ticker: GOOGL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 38920117)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.93)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00198)
#   Expected Move: 2.94%
#
# Processing GOOG...
# Ticker: GOOG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 25499543)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.95)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00240)
#   Expected Move: 2.94%
#
# Processing MO...
# Ticker: MO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 12751387)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.88)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01102)
#   Expected Move: 1.91%
#
# Processing AMZN...
# Ticker: AMZN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 57270267)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.75)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00943)
#   Expected Move: 3.79%
#
# Processing AMCR...
# Ticker: AMCR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 34345790)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.06)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.24%
#
# Processing AEE...
# Ticker: AEE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2149940)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.95)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.11%
#
# Processing AEP...
# Ticker: AEP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5317930)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.00)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.3%
#
# Processing AXP...
# Ticker: AXP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4188683)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.75)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02656)
#   Expected Move: 5.22%
#
# Processing AIG...
# Ticker: AIG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6300600)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.92)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00375)
#   Expected Move: 2.48%
#
# Processing AMT...
# Ticker: AMT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3506347)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.86)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.15%
#
# Processing AWK...
# Ticker: AWK
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1886987)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.92)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 1.83%
#
# Processing AMP...
# Ticker: AMP
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 613113)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.84)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.29%
#
# Processing AME...
# Ticker: AME
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1606877)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.05)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 1.1%
#
# Processing AMGN...
# Ticker: AMGN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3348617)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.04)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00953)
#   Expected Move: 2.69%
#
# Processing APH...
# Ticker: APH
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 9327500)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.94)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.02%
#
# Processing ADI...
# Ticker: ADI
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4679087)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.76)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.03429)
#   Expected Move: 6.22%
#
# Processing ANSS...
# Ticker: ANSS
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 613440)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.52)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.77%
#
# Processing AON...
# Ticker: AON
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1418960)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.01)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.53%
#
# Processing APA...
# Ticker: APA
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 9620733)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.94)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01611)
#   Expected Move: 6.41%
#
# Processing APO...
# Ticker: APO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5418413)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.65)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01936)
#   Expected Move: 5.26%
#
# Processing AAPL...
# Ticker: AAPL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 71531510)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.68)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01432)
#   Expected Move: 4.27%
#
# Processing AMAT...
# Ticker: AMAT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 8743253)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.82)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02103)
#   Expected Move: 5.36%
#
# Processing APTV...
# Ticker: APTV
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4396033)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.00)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.34%
#
# Processing ACGL...
# Ticker: ACGL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1834380)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.05)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.74%
#
# Processing ADM...
# Ticker: ADM
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 5768343)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.98)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.00391)
#   Expected Move: 3.23%
#
# Processing ANET...
# Ticker: ANET
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 12276267)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.79)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00797)
#   Expected Move: 4.79%
#
# Processing AJG...
# Ticker: AJG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1708997)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.98)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.94%
#
# Processing AIZ...
# Ticker: AIZ
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 508910)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.15)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.83%
#
# Processing T...
# Ticker: T
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 48283347)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.83)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.01422)
#   Expected Move: 2.35%
#
# Processing ATO...
# Ticker: ATO
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1036877)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.07)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 1.63%
#
# Processing ADSK...
# Ticker: ADSK
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1908700)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.91)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01308)
#   Expected Move: 3.46%
#
# Processing ADP...
# Ticker: ADP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2283410)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.19)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00557)
#   Expected Move: 2.12%
#
# Processing AZO...
# Ticker: AZO
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 176630)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.81)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.17%
#
# Processing AVB...
# Ticker: AVB
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 914890)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.83)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.87%
#
# Processing AVY...
# Ticker: AVY
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 891743)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.32)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.8%
#
# Processing AXON...
# Ticker: AXON
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 782523)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.06)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.65%
#
# Processing BKR...
# Ticker: BKR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 9370557)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.87)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.23%
#
# Processing BALL...
# Ticker: BALL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2751270)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.13)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.48%
#
# Processing BAC...
# Ticker: BAC
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 58168990)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.67)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02164)
#   Expected Move: 4.66%
#
# Processing BAX...
# Ticker: BAX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4842467)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.11)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00940)
#   Expected Move: 4.23%
#
# Processing BDX...
# Ticker: BDX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2297093)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.04)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.98%
#
# Processing BRK-B...
# Ticker: BRK-B
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6063630)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.69)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00459)
#   Expected Move: 2.1%
#
# Processing BBY...
# Ticker: BBY
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5277823)
#   iv30/rv30 <= 0.64: PASS (iv30/rv30 = 0.63)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02008)
#   Expected Move: 5.38%
#
# Processing TECH...
# Ticker: TECH
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2225303)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.01)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 11.13%
#
# Processing BIIB...
# Ticker: BIIB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1911123)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.23)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01105)
#   Expected Move: 2.73%
#
# Processing BLK...
# Ticker: BLK
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1097503)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.76)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00551)
#   Expected Move: 3.34%
#
# Processing BX...
# Ticker: BX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6450920)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.77)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.03340)
#   Expected Move: 6.25%
#
# Processing BK...
# Ticker: BK
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4798820)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.88)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02995)
#   Expected Move: 3.1%
#
# Processing BA...
# Ticker: BA
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 10374657)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.77)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00367)
#   Expected Move: 4.55%
#
# Processing BKNG...
# Ticker: BKNG
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 325703)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.95)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00844)
#   Expected Move: 2.94%
#
# Processing BSX...
# Ticker: BSX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 9771157)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.85)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00389)
#   Expected Move: 4.46%
#
# Processing BMY...
# Ticker: BMY
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 13625570)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.06)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00644)
#   Expected Move: 3.46%
#
# Processing AVGO...
# Ticker: AVGO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 39404793)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.65)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01904)
#   Expected Move: 5.51%
#
# Processing BR...
# Ticker: BR
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 652840)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.02)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.26%
#
# Processing BRO...
# Ticker: BRO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2030070)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.12)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.6%
#
# Processing BF-B...
# Ticker: BF-B
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3752027)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.93)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 7.04%
#
# Processing BLDR...
# Ticker: BLDR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1777107)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.04)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.73%
#
# Processing BG...
# Ticker: BG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1970467)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.02)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.72%
#
# Processing BXP...
# Ticker: BXP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1671700)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.89)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.98%
#
# Processing CHRW...
# Ticker: CHRW
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1622987)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.22)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.6%
#
# Processing CDNS...
# Ticker: CDNS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2463543)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.96)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.84%
#
# Processing CZR...
# Ticker: CZR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6644510)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.89)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00958)
#   Expected Move: 4.53%
#
# Processing CPT...
# Ticker: CPT
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1170363)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.38)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.18%
#
# Processing CPB...
# Ticker: CPB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4087693)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.65)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02615)
#   Expected Move: 2.83%
#
# Processing COF...
# Ticker: COF
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5809693)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.73)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00545)
#   Expected Move: 4.61%
#
# Processing CAH...
# Ticker: CAH
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2775803)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.18)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.04182)
#   Expected Move: 2.52%
#
# Processing KMX...
# Ticker: KMX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3823583)
#   iv30/rv30 <= 0.64: PASS (iv30/rv30 = 0.64)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.15%
#
# Processing CCL...
# Ticker: CCL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 32012057)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.67)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01147)
#   Expected Move: 4.94%
#
# Processing CARR...
# Ticker: CARR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5445307)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.92)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.75%
#
# Processing CAT...
# Ticker: CAT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3267500)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.77)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01273)
#   Expected Move: 3.25%
#
# Processing CBOE...
# Ticker: CBOE
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1050837)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.93)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02093)
#   Expected Move: 2.51%
#
# Processing CBRE...
# Ticker: CBRE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2197153)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.92)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.49%
#
# Processing CDW...
# Ticker: CDW
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1747533)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.17)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.55%
#
# Processing COR...
# Ticker: COR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2020710)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.98)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.43%
#
# Processing CNC...
# Ticker: CNC
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4623620)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.99)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.00473)
#   Expected Move: 3.49%
#
# Processing CNP...
# Ticker: CNP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6443990)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.16)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.01%
#
# Processing CF...
# Ticker: CF
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3017480)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.04)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01990)
#   Expected Move: 3.56%
#
# Processing CRL...
# Ticker: CRL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1819590)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.03)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 7.2%
#
# Processing SCHW...
# Ticker: SCHW
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 12337430)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.81)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.03477)
#   Expected Move: 5.67%
#
# Processing CHTR...
# Ticker: CHTR
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1488720)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.13)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.02855)
#   Expected Move: 3.5%
#
# Processing CVX...
# Ticker: CVX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 11145537)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.89)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01138)
#   Expected Move: 3.28%
#
# Processing CMG...
# Ticker: CMG
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 14666343)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.00)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.01651)
#   Expected Move: 3.5%
#
# Processing CB...
# Ticker: CB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2072263)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.09)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.72%
#
# Processing CHD...
# Ticker: CHD
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1817187)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.16)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.06%
#
# Processing CI...
# Ticker: CI
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1830253)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.11)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01309)
#   Expected Move: 2.38%
#
# Processing CINF...
# Ticker: CINF
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 960593)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.07)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.34%
#
# Processing CTAS...
# Ticker: CTAS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2297020)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.87)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02636)
#   Expected Move: 2.44%
#
# Processing CSCO...
# Ticker: CSCO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 26853960)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.05)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00986)
#   Expected Move: 2.67%
#
# Processing C...
# Ticker: C
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 21164387)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.72)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02270)
#   Expected Move: 4.94%
#
# Processing CFG...
# Ticker: CFG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6068250)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.88)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.55%
#
# Processing CLX...
# Ticker: CLX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1597143)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.20)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.41%
#
# Processing CME...
# Ticker: CME
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3240240)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.00)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.71%
#
# Processing CMS...
# Ticker: CMS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2750717)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.39)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.56%
#
# Processing KO...
# Ticker: KO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 20794897)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.81)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00259)
#   Expected Move: 1.61%
#
# Processing CTSH...
# Ticker: CTSH
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4629057)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.03)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.92%
#
# Processing CL...
# Ticker: CL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5892297)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.88)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01869)
#   Expected Move: 2.55%
#
# Processing CMCSA...
# Ticker: CMCSA
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 29465567)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.29)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.01746)
#   Expected Move: 2.34%
#
# Processing CAG...
# Ticker: CAG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6991450)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.74)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01752)
#   Expected Move: 2.39%
#
# Processing COP...
# Ticker: COP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 11443497)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.90)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01254)
#   Expected Move: 4.57%
#
# Processing ED...
# Ticker: ED
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3233470)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.94)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.47%
#
# Processing STZ...
# Ticker: STZ
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2741443)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.73)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00665)
#   Expected Move: 2.31%
#
# Processing CEG...
# Ticker: CEG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4754413)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.77)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01788)
#   Expected Move: 5.08%
#
# Processing COO...
# Ticker: COO
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2495163)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.17)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.05%
#
# Processing CPRT...
# Ticker: CPRT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5663723)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.23)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.21%
#
# Processing GLW...
# Ticker: GLW
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 7466270)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.82)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01108)
#   Expected Move: 3.66%
#
# Processing CPAY...
# Ticker: CPAY
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 531237)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.98)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.86%
#
# Processing CTVA...
# Ticker: CTVA
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3869107)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.40)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.4%
#
# Processing CSGP...
# Ticker: CSGP
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3659230)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.12)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.99%
#
# Processing COST...
# Ticker: COST
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2917113)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.67)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00670)
#   Expected Move: 2.44%
#
# Processing CTRA...
# Ticker: CTRA
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 7949467)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.12)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.01202)
#   Expected Move: 3.97%
#
# Processing CRWD...
# Ticker: CRWD
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5200120)
#   iv30/rv30 <= 0.64: PASS (iv30/rv30 = 0.61)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01108)
#   Expected Move: 4.63%
#
# Processing CCI...
# Ticker: CCI
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4381080)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.75)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.53%
#
# Processing CSX...
# Ticker: CSX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 17330590)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.26)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00439)
#   Expected Move: 4.07%
#
# Processing CMI...
# Ticker: CMI
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1066763)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.78)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.62%
#
# Processing CVS...
# Ticker: CVS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 10161033)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.78)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01633)
#   Expected Move: 2.98%
#
# Processing DHR...
# Ticker: DHR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4535200)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.07)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01785)
#   Expected Move: 3.69%
#
# Processing DRI...
# Ticker: DRI
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1466603)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.79)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.53%
#
# Processing DVA...
# Ticker: DVA
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 913050)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.26)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.33%
#
# Processing DAY...
# Ticker: DAY
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2177000)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.24)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.54%
#
# Processing DECK...
# Ticker: DECK
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3673293)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.71)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01118)
#   Expected Move: 5.51%
#
# Processing DE...
# Ticker: DE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1609273)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.91)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00887)
#   Expected Move: 2.93%
#
# Processing DELL...
# Ticker: DELL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 9309940)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.71)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01659)
#   Expected Move: 5.9%
#
# Processing DAL...
# Ticker: DAL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 16087707)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.69)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02258)
#   Expected Move: 5.68%
#
# Processing DVN...
# Ticker: DVN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 10721343)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.92)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01672)
#   Expected Move: 5.26%
#
# Processing DXCM...
# Ticker: DXCM
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4882050)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.11)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01559)
#   Expected Move: 3.86%
#
# Processing FANG...
# Ticker: FANG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3209963)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.85)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01369)
#   Expected Move: 5.07%
#
# Processing DLR...
# Ticker: DLR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2685817)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.86)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01013)
#   Expected Move: 2.43%
#
# Processing DFS...
# Ticker: DFS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2698703)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.86)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00198)
#   Expected Move: 5.12%
#
# Processing DG...
# Ticker: DG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5463783)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.79)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01239)
#   Expected Move: 3.14%
#
# Processing DLTR...
# Ticker: DLTR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6732183)
#   iv30/rv30 <= 0.64: PASS (iv30/rv30 = 0.61)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00858)
#   Expected Move: 4.31%
#
# Processing D...
# Ticker: D
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5597867)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.03)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 1.62%
#
# Processing DPZ...
# Ticker: DPZ
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 749093)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.99)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02577)
#   Expected Move: 3.34%
#
# Processing DASH...
# Ticker: DASH
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 8426703)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.90)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00776)
#   Expected Move: 4.26%
#
# Processing DOV...
# Ticker: DOV
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1294503)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.85)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.16%
#
# Processing DOW...
# Ticker: DOW
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 9641887)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.86)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.00989)
#   Expected Move: 4.09%
#
# Processing DHI...
# Ticker: DHI
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3953517)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.97)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.03798)
#   Expected Move: 6.36%
#
# Processing DTE...
# Ticker: DTE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1647397)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.12)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.27%
#
# Processing DUK...
# Ticker: DUK
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4996157)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.94)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.2%
#
# Processing DD...
# Ticker: DD
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3530517)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.68)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01611)
#   Expected Move: 3.08%
#
# Processing EMN...
# Ticker: EMN
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1444580)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.98)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.65%
#
# Processing ETN...
# Ticker: ETN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4130207)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.69)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00168)
#   Expected Move: 3.82%
#
# Processing EBAY...
# Ticker: EBAY
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6176057)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.03)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01190)
#   Expected Move: 3.18%
#
# Processing ECL...
# Ticker: ECL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1633160)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.03)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.39%
#
# Processing EIX...
# Ticker: EIX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4086507)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.15)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.15%
#
# Processing EW...
# Ticker: EW
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5038180)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.20)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.4%
#
# Processing EA...
# Ticker: EA
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3703827)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.31)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.61%
#
# Processing ELV...
# Ticker: ELV
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1829827)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.90)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.31%
#
# Processing EMR...
# Ticker: EMR
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 3685923)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.87)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.00888)
#   Expected Move: 3.51%
#
# Processing ENPH...
# Ticker: ENPH
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 3872467)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.02)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.03580)
#   Expected Move: 5.69%
#
# Processing ETR...
# Ticker: ETR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5115367)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.91)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.45%
#
# Processing EOG...
# Ticker: EOG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4632670)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.97)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02521)
#   Expected Move: 4.27%
#
# Processing EPAM...
# Ticker: EPAM
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 795047)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.11)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.3%
#
# Processing EQT...
# Ticker: EQT
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 8968147)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.78)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00720)
#   Expected Move: 4.6%
#
# Processing EFX...
# Ticker: EFX
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1213620)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.18)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.25%
#
# Processing EQIX...
# Ticker: EQIX
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 815480)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.96)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.46%
#
# Processing EQR...
# Ticker: EQR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2012563)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.84)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.39%
#
# Processing ERIE...
# Ticker: ERIE
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 138947)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.25)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.7%
#
# Processing ESS...
# Ticker: ESS
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 506177)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.99)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.89%
#
# Processing EL...
# Ticker: EL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4452833)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.06)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01102)
#   Expected Move: 5.23%
#
# Processing EG...
# Ticker: EG
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 433773)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.05)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.14%
#
# Processing EVRG...
# Ticker: EVRG
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2827040)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.24)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.55%
#
# Processing ES...
# Ticker: ES
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2671257)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.92)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.08%
#
# Processing EXC...
# Ticker: EXC
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 9886390)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.99)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.69%
#
# Processing EXE...
# Ticker: EXE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 6407760)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.95)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.28%
#
# Processing EXPE...
# Ticker: EXPE
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2742557)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.94)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00494)
#   Expected Move: 3.75%
#
# Processing EXPD...
# Ticker: EXPD
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1785793)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.93)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.73%
#
# Processing EXR...
# Ticker: EXR
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 1317967)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.16)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.09%
#
# Processing XOM...
# Ticker: XOM
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 20373530)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.89)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01151)
#   Expected Move: 3.4%
#
# Processing FFIV...
# Ticker: FFIV
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 604740)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.07)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.97%
#
# Processing FDS...
# Ticker: FDS
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 348440)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.99)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.42%
#
# Processing FICO...
# Ticker: FICO
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 195167)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.02)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.19%
#
# Processing FAST...
# Ticker: FAST
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4358307)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.74)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.64%
#
# Processing FRT...
# Ticker: FRT
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 985853)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.94)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 4.44%
#
# Processing FDX...
# Ticker: FDX
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2442017)
#   iv30/rv30 <= 0.64: PASS (iv30/rv30 = 0.63)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00993)
#   Expected Move: 3.58%
#
# Processing FIS...
# Ticker: FIS
#   Classification: Consider
#   avg_volume >= 1.5M: PASS (30-day MA = 4042763)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.43)
#   ts_slope (Nearest vs. 4-20 days): PASS (Slope = 0.03076)
#   Expected Move: 3.47%
#
# Processing FITB...
# Ticker: FITB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 5951450)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.96)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.06%
#
# Processing FSLR...
# Ticker: FSLR
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3477787)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.04)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01055)
#   Expected Move: 5.19%
#
# Processing FE...
#   Data unavailable or incomplete for FE. Skipping.
#
# Processing FI...
#   Data unavailable or incomplete for FI. Skipping.
#
# Processing F...
#   Data unavailable or incomplete for F. Skipping.
#
# Processing FTNT...
#   Data unavailable or incomplete for FTNT. Skipping.
#
# Processing FTV...
#   Data unavailable or incomplete for FTV. Skipping.
#
# Processing FOXA...
#   Data unavailable or incomplete for FOXA. Skipping.
#
# Processing FOX...
#   Data unavailable or incomplete for FOX. Skipping.
#
# Processing BEN...
#   Data unavailable or incomplete for BEN. Skipping.
#
# Processing FCX...
#   Data unavailable or incomplete for FCX. Skipping.
#
# Processing GRMN...
#   Data unavailable or incomplete for GRMN. Skipping.
#
# Processing IT...
#   Data unavailable or incomplete for IT. Skipping.
#
# Processing GE...
#   Data unavailable or incomplete for GE. Skipping.
#
# Processing GEHC...
#   Data unavailable or incomplete for GEHC. Skipping.
#
# Processing GEV...
#   Data unavailable or incomplete for GEV. Skipping.
#
# Processing GEN...
#   Data unavailable or incomplete for GEN. Skipping.
#
# Processing GNRC...
#   Data unavailable or incomplete for GNRC. Skipping.
#
# Processing GD...
#   Data unavailable or incomplete for GD. Skipping.
#
# Processing GIS...
#   Data unavailable or incomplete for GIS. Skipping.
#
# Processing GM...
#   Data unavailable or incomplete for GM. Skipping.
#
# Processing GPC...
#   Data unavailable or incomplete for GPC. Skipping.
#
# ...
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.91)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.97%
#
# Processing WSM...
# Ticker: WSM
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 3773500)
#   iv30/rv30 <= 0.64: PASS (iv30/rv30 = 0.60)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 5.71%
#
# Processing WMB...
# Ticker: WMB
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 8727863)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.07)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.02322)
#   Expected Move: 3.14%
#
# Processing WTW...
# Ticker: WTW
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 719670)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.12)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.25%
#
# Processing WDAY...
# Ticker: WDAY
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2506347)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.90)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.01634)
#   Expected Move: 3.41%
#
# Processing WYNN...
# Ticker: WYNN
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2840867)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.98)
#   ts_slope (Nearest vs. 4-20 days): FAIL (Slope = -0.00082)
#   Expected Move: 4.32%
#
# Processing XEL...
# Ticker: XEL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 4072080)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.05)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.39%
#
# Processing XYL...
# Ticker: XYL
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 1942653)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.14)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.44%
#
# Processing YUM...
# Ticker: YUM
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2575967)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.98)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 2.93%
#
# Processing ZBRA...
# Ticker: ZBRA
#   Classification: Avoid
#   avg_volume >= 1.5M: FAIL (30-day MA = 723007)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 0.92)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.74%
#
# Processing ZBH...
# Ticker: ZBH
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2101603)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.10)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.26%
#
# Processing ZTS...
# Ticker: ZTS
#   Classification: Avoid
#   avg_volume >= 1.5M: PASS (30-day MA = 2788427)
#   iv30/rv30 <= 0.64: FAIL (iv30/rv30 = 1.14)
#   ts_slope: Unable to compute (no expiration found between 4-20 days)
#   Expected Move: 3.12%
#
#
# Final Screening Results:
# Ticker: MMM  ->  Classification: Consider
# Ticker: AOS  ->  Classification: Avoid
# Ticker: ABT  ->  Classification: Avoid
# Ticker: ABBV  ->  Classification: Consider
# Ticker: ACN  ->  Classification: Avoid
# Ticker: ADBE  ->  Classification: Avoid
# Ticker: AMD  ->  Classification: Avoid
# Ticker: AES  ->  Classification: Avoid
# Ticker: AFL  ->  Classification: Avoid
# Ticker: A  ->  Classification: Avoid
# Ticker: APD  ->  Classification: Avoid
# Ticker: ABNB  ->  Classification: Avoid
# Ticker: AKAM  ->  Classification: Avoid
# Ticker: ALB  ->  Classification: Avoid
# Ticker: ARE  ->  Classification: Avoid
# Ticker: ALGN  ->  Classification: Avoid
# Ticker: ALLE  ->  Classification: Avoid
# Ticker: LNT  ->  Classification: Avoid
# Ticker: ALL  ->  Classification: Avoid
# Ticker: GOOGL  ->  Classification: Avoid
# Ticker: GOOG  ->  Classification: Avoid
# Ticker: MO  ->  Classification: Avoid
# Ticker: AMZN  ->  Classification: Avoid
# Ticker: AMCR  ->  Classification: Avoid
# Ticker: AEE  ->  Classification: Avoid
# Ticker: AEP  ->  Classification: Avoid
# Ticker: AXP  ->  Classification: Avoid
# Ticker: AIG  ->  Classification: Avoid
# Ticker: AMT  ->  Classification: Avoid
# Ticker: AWK  ->  Classification: Avoid
# Ticker: AMP  ->  Classification: Avoid
# Ticker: AME  ->  Classification: Avoid
# Ticker: AMGN  ->  Classification: Avoid
# Ticker: APH  ->  Classification: Avoid
# Ticker: ADI  ->  Classification: Avoid
# Ticker: ANSS  ->  Classification: Avoid
# Ticker: AON  ->  Classification: Avoid
# Ticker: APA  ->  Classification: Avoid
# Ticker: APO  ->  Classification: Avoid
# Ticker: AAPL  ->  Classification: Avoid
# Ticker: AMAT  ->  Classification: Avoid
# Ticker: APTV  ->  Classification: Avoid
# Ticker: ACGL  ->  Classification: Avoid
# Ticker: ADM  ->  Classification: Consider
# Ticker: ANET  ->  Classification: Avoid
# Ticker: AJG  ->  Classification: Avoid
# Ticker: AIZ  ->  Classification: Avoid
# Ticker: T  ->  Classification: Consider
# Ticker: ATO  ->  Classification: Avoid
# Ticker: ADSK  ->  Classification: Avoid
# Ticker: ADP  ->  Classification: Avoid
# Ticker: AZO  ->  Classification: Avoid
# Ticker: AVB  ->  Classification: Avoid
# Ticker: AVY  ->  Classification: Avoid
# Ticker: AXON  ->  Classification: Avoid
# Ticker: BKR  ->  Classification: Avoid
# Ticker: BALL  ->  Classification: Avoid
# Ticker: BAC  ->  Classification: Avoid
# Ticker: BAX  ->  Classification: Avoid
# Ticker: BDX  ->  Classification: Avoid
# Ticker: BRK-B  ->  Classification: Avoid
# Ticker: BBY  ->  Classification: Avoid
# Ticker: TECH  ->  Classification: Avoid
# Ticker: BIIB  ->  Classification: Avoid
# Ticker: BLK  ->  Classification: Avoid
# Ticker: BX  ->  Classification: Avoid
# Ticker: BK  ->  Classification: Avoid
# Ticker: BA  ->  Classification: Avoid
# Ticker: BKNG  ->  Classification: Avoid
# Ticker: BSX  ->  Classification: Avoid
# Ticker: BMY  ->  Classification: Avoid
# Ticker: AVGO  ->  Classification: Avoid
# Ticker: BR  ->  Classification: Avoid
# Ticker: BRO  ->  Classification: Avoid
# Ticker: BF-B  ->  Classification: Avoid
# Ticker: BLDR  ->  Classification: Avoid
# Ticker: BG  ->  Classification: Avoid
# Ticker: BXP  ->  Classification: Avoid
# Ticker: CHRW  ->  Classification: Avoid
# Ticker: CDNS  ->  Classification: Avoid
# Ticker: CZR  ->  Classification: Avoid
# Ticker: CPT  ->  Classification: Avoid
# Ticker: CPB  ->  Classification: Avoid
# Ticker: COF  ->  Classification: Avoid
# Ticker: CAH  ->  Classification: Avoid
# Ticker: KMX  ->  Classification: Avoid
# Ticker: CCL  ->  Classification: Avoid
# Ticker: CARR  ->  Classification: Avoid
# Ticker: CAT  ->  Classification: Avoid
# Ticker: CBOE  ->  Classification: Avoid
# Ticker: CBRE  ->  Classification: Avoid
# Ticker: CDW  ->  Classification: Avoid
# Ticker: COR  ->  Classification: Avoid
# Ticker: CNC  ->  Classification: Consider
# Ticker: CNP  ->  Classification: Avoid
# Ticker: CF  ->  Classification: Avoid
# Ticker: CRL  ->  Classification: Avoid
# Ticker: SCHW  ->  Classification: Avoid
# Ticker: CHTR  ->  Classification: Avoid
# Ticker: CVX  ->  Classification: Avoid
# Ticker: CMG  ->  Classification: Consider
# Ticker: CB  ->  Classification: Avoid
# Ticker: CHD  ->  Classification: Avoid
# Ticker: CI  ->  Classification: Avoid
# Ticker: CINF  ->  Classification: Avoid
# Ticker: CTAS  ->  Classification: Avoid
# Ticker: CSCO  ->  Classification: Avoid
# Ticker: C  ->  Classification: Avoid
# Ticker: CFG  ->  Classification: Avoid
# Ticker: CLX  ->  Classification: Avoid
# Ticker: CME  ->  Classification: Avoid
# Ticker: CMS  ->  Classification: Avoid
# Ticker: KO  ->  Classification: Avoid
# Ticker: CTSH  ->  Classification: Avoid
# Ticker: CL  ->  Classification: Avoid
# Ticker: CMCSA  ->  Classification: Consider
# Ticker: CAG  ->  Classification: Avoid
# Ticker: COP  ->  Classification: Avoid
# Ticker: ED  ->  Classification: Avoid
# Ticker: STZ  ->  Classification: Avoid
# Ticker: CEG  ->  Classification: Avoid
# Ticker: COO  ->  Classification: Avoid
# Ticker: CPRT  ->  Classification: Avoid
# Ticker: GLW  ->  Classification: Avoid
# Ticker: CPAY  ->  Classification: Avoid
# Ticker: CTVA  ->  Classification: Avoid
# Ticker: CSGP  ->  Classification: Avoid
# Ticker: COST  ->  Classification: Avoid
# Ticker: CTRA  ->  Classification: Consider
# Ticker: CRWD  ->  Classification: Avoid
# Ticker: CCI  ->  Classification: Avoid
# Ticker: CSX  ->  Classification: Avoid
# Ticker: CMI  ->  Classification: Avoid
# Ticker: CVS  ->  Classification: Avoid
# Ticker: DHR  ->  Classification: Avoid
# Ticker: DRI  ->  Classification: Avoid
# Ticker: DVA  ->  Classification: Avoid
# Ticker: DAY  ->  Classification: Avoid
# Ticker: DECK  ->  Classification: Avoid
# Ticker: DE  ->  Classification: Avoid
# Ticker: DELL  ->  Classification: Avoid
# Ticker: DAL  ->  Classification: Avoid
# Ticker: DVN  ->  Classification: Avoid
# Ticker: DXCM  ->  Classification: Avoid
# Ticker: FANG  ->  Classification: Avoid
# Ticker: DLR  ->  Classification: Avoid
# Ticker: DFS  ->  Classification: Avoid
# Ticker: DG  ->  Classification: Avoid
# Ticker: DLTR  ->  Classification: Avoid
# Ticker: D  ->  Classification: Avoid
# Ticker: DPZ  ->  Classification: Avoid
# Ticker: DASH  ->  Classification: Avoid
# Ticker: DOV  ->  Classification: Avoid
# Ticker: DOW  ->  Classification: Consider
# Ticker: DHI  ->  Classification: Avoid
# Ticker: DTE  ->  Classification: Avoid
# Ticker: DUK  ->  Classification: Avoid
# Ticker: DD  ->  Classification: Avoid
# Ticker: EMN  ->  Classification: Avoid
# Ticker: ETN  ->  Classification: Avoid
# Ticker: EBAY  ->  Classification: Avoid
# Ticker: ECL  ->  Classification: Avoid
# Ticker: EIX  ->  Classification: Avoid
# Ticker: EW  ->  Classification: Avoid
# Ticker: EA  ->  Classification: Avoid
# Ticker: ELV  ->  Classification: Avoid
# Ticker: EMR  ->  Classification: Consider
# Ticker: ENPH  ->  Classification: Consider
# Ticker: ETR  ->  Classification: Avoid
# Ticker: EOG  ->  Classification: Avoid
# Ticker: EPAM  ->  Classification: Avoid
# Ticker: EQT  ->  Classification: Avoid
# Ticker: EFX  ->  Classification: Avoid
# Ticker: EQIX  ->  Classification: Avoid
# Ticker: EQR  ->  Classification: Avoid
# Ticker: ERIE  ->  Classification: Avoid
# Ticker: ESS  ->  Classification: Avoid
# Ticker: EL  ->  Classification: Avoid
# Ticker: EG  ->  Classification: Avoid
# Ticker: EVRG  ->  Classification: Avoid
# Ticker: ES  ->  Classification: Avoid
# Ticker: EXC  ->  Classification: Avoid
# Ticker: EXE  ->  Classification: Avoid
# Ticker: EXPE  ->  Classification: Avoid
# Ticker: EXPD  ->  Classification: Avoid
# Ticker: EXR  ->  Classification: Avoid
# Ticker: XOM  ->  Classification: Avoid
# Ticker: FFIV  ->  Classification: Avoid
# Ticker: FDS  ->  Classification: Avoid
# Ticker: FICO  ->  Classification: Avoid
# Ticker: FAST  ->  Classification: Avoid
# Ticker: FRT  ->  Classification: Avoid
# Ticker: FDX  ->  Classification: Avoid
# Ticker: FIS  ->  Classification: Consider
# Ticker: FITB  ->  Classification: Avoid
# Ticker: FSLR  ->  Classification: Avoid
# Ticker: KMI  ->  Classification: Avoid
# Ticker: KKR  ->  Classification: Avoid
# Ticker: KLAC  ->  Classification: Avoid
# Ticker: KHC  ->  Classification: Avoid
# Ticker: KR  ->  Classification: Avoid
# Ticker: LHX  ->  Classification: Avoid
# Ticker: LH  ->  Classification: Avoid
# Ticker: LRCX  ->  Classification: Avoid
# Ticker: LW  ->  Classification: Avoid
# Ticker: LVS  ->  Classification: Avoid
# Ticker: LDOS  ->  Classification: Avoid
# Ticker: LEN  ->  Classification: Avoid
# Ticker: LII  ->  Classification: Avoid
# Ticker: LLY  ->  Classification: Avoid
# Ticker: LIN  ->  Classification: Avoid
# Ticker: LYV  ->  Classification: Avoid
# Ticker: LKQ  ->  Classification: Avoid
# Ticker: LMT  ->  Classification: Consider
# Ticker: L  ->  Classification: Avoid
# Ticker: LOW  ->  Classification: Avoid
# Ticker: LULU  ->  Classification: Avoid
# Ticker: LYB  ->  Classification: Avoid
# Ticker: MTB  ->  Classification: Avoid
# Ticker: MPC  ->  Classification: Avoid
# Ticker: MKTX  ->  Classification: Avoid
# Ticker: MAR  ->  Classification: Avoid
# Ticker: MMC  ->  Classification: Avoid
# Ticker: MLM  ->  Classification: Avoid
# Ticker: MAS  ->  Classification: Avoid
# Ticker: MA  ->  Classification: Avoid
# Ticker: MTCH  ->  Classification: Avoid
# Ticker: MKC  ->  Classification: Avoid
# Ticker: MCD  ->  Classification: Avoid
# Ticker: MCK  ->  Classification: Avoid
# Ticker: MDT  ->  Classification: Avoid
# Ticker: MRK  ->  Classification: Consider
# Ticker: META  ->  Classification: Avoid
# Ticker: MET  ->  Classification: Avoid
# Ticker: MTD  ->  Classification: Avoid
# Ticker: MGM  ->  Classification: Avoid
# Ticker: MCHP  ->  Classification: Avoid
# Ticker: MU  ->  Classification: Avoid
# Ticker: MSFT  ->  Classification: Avoid
# Ticker: MAA  ->  Classification: Avoid
# Ticker: MRNA  ->  Classification: Avoid
# Ticker: MHK  ->  Classification: Avoid
# Ticker: MOH  ->  Classification: Avoid
# Ticker: TAP  ->  Classification: Avoid
# Ticker: MDLZ  ->  Classification: Avoid
# Ticker: MPWR  ->  Classification: Avoid
# Ticker: MNST  ->  Classification: Consider
# Ticker: MCO  ->  Classification: Avoid
# Ticker: MS  ->  Classification: Avoid
# Ticker: MOS  ->  Classification: Avoid
# Ticker: MSI  ->  Classification: Avoid
# Ticker: MSCI  ->  Classification: Avoid
# Ticker: NDAQ  ->  Classification: Avoid
# Ticker: NTAP  ->  Classification: Avoid
# Ticker: NFLX  ->  Classification: Avoid
# Ticker: NEM  ->  Classification: Avoid
# Ticker: NWSA  ->  Classification: Avoid
# Ticker: NEE  ->  Classification: Avoid
# Ticker: NKE  ->  Classification: Avoid
# Ticker: NI  ->  Classification: Avoid
# Ticker: NDSN  ->  Classification: Avoid
# Ticker: NSC  ->  Classification: Avoid
# Ticker: NTRS  ->  Classification: Avoid
# Ticker: NOC  ->  Classification: Avoid
# Ticker: NCLH  ->  Classification: Avoid
# Ticker: NRG  ->  Classification: Avoid
# Ticker: NUE  ->  Classification: Avoid
# Ticker: NVDA  ->  Classification: Avoid
# Ticker: NXPI  ->  Classification: Avoid
# Ticker: ORLY  ->  Classification: Avoid
# Ticker: OXY  ->  Classification: Avoid
# Ticker: ODFL  ->  Classification: Avoid
# Ticker: OMC  ->  Classification: Avoid
# Ticker: ON  ->  Classification: Avoid
# Ticker: OKE  ->  Classification: Avoid
# Ticker: ORCL  ->  Classification: Avoid
# Ticker: OTIS  ->  Classification: Avoid
# Ticker: PCAR  ->  Classification: Avoid
# Ticker: PKG  ->  Classification: Avoid
# Ticker: PLTR  ->  Classification: Avoid
# Ticker: PANW  ->  Classification: Avoid
# Ticker: PARA  ->  Classification: Avoid
# Ticker: PH  ->  Classification: Avoid
# Ticker: PAYX  ->  Classification: Avoid
# Ticker: TFC  ->  Classification: Avoid
# Ticker: TYL  ->  Classification: Avoid
# Ticker: TSN  ->  Classification: Avoid
# Ticker: USB  ->  Classification: Avoid
# Ticker: UBER  ->  Classification: Avoid
# Ticker: UDR  ->  Classification: Avoid
# Ticker: ULTA  ->  Classification: Avoid
# Ticker: UNP  ->  Classification: Consider
# Ticker: UAL  ->  Classification: Avoid
# Ticker: UPS  ->  Classification: Avoid
# Ticker: URI  ->  Classification: Avoid
# Ticker: UNH  ->  Classification: Avoid
# Ticker: UHS  ->  Classification: Avoid
# Ticker: VLO  ->  Classification: Consider
# Ticker: VTR  ->  Classification: Avoid
# Ticker: VLTO  ->  Classification: Avoid
# Ticker: VRSN  ->  Classification: Avoid
# Ticker: VRSK  ->  Classification: Avoid
# Ticker: VZ  ->  Classification: Consider
# Ticker: VRTX  ->  Classification: Avoid
# Ticker: VTRS  ->  Classification: Avoid
# Ticker: VICI  ->  Classification: Avoid
# Ticker: V  ->  Classification: Avoid
# Ticker: VST  ->  Classification: Avoid
# Ticker: VMC  ->  Classification: Avoid
# Ticker: WRB  ->  Classification: Avoid
# Ticker: GWW  ->  Classification: Avoid
# Ticker: WAB  ->  Classification: Avoid
# Ticker: WBA  ->  Classification: Avoid
# Ticker: WMT  ->  Classification: Avoid
# Ticker: DIS  ->  Classification: Avoid
# Ticker: WBD  ->  Classification: Avoid
# Ticker: WM  ->  Classification: Avoid
# Ticker: WAT  ->  Classification: Avoid
# Ticker: WEC  ->  Classification: Avoid
# Ticker: WFC  ->  Classification: Avoid
# Ticker: WELL  ->  Classification: Avoid
# Ticker: WST  ->  Classification: Avoid
# Ticker: WDC  ->  Classification: Avoid
# Ticker: WY  ->  Classification: Avoid
# Ticker: WSM  ->  Classification: Avoid
# Ticker: WMB  ->  Classification: Avoid
# Ticker: WTW  ->  Classification: Avoid
# Ticker: WDAY  ->  Classification: Avoid
# Ticker: WYNN  ->  Classification: Avoid
# Ticker: XEL  ->  Classification: Avoid
# Ticker: XYL  ->  Classification: Avoid
# Ticker: YUM  ->  Classification: Avoid
# Ticker: ZBRA  ->  Classification: Avoid
# Ticker: ZBH  ->  Classification: Avoid
# Ticker: ZTS  ->  Classification: Avoid
