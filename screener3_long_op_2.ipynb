# %%
# -*- coding: utf-8 -*-
"""
DISCLAIMER: 

This software is provided solely for educational and research purposes. 
It is not intended to provide investment advice, and no investment recommendations are made herein. 
The developers are not financial advisors and accept no responsibility for any financial decisions or losses resulting from the use of this software. 
Always consult a professional financial advisor before making any investment decisions.
"""

import yfinance as yf
import pandas as pd
import numpy as np
import pandas_ta as ta # For technical indicators
from datetime import datetime, timedelta
from scipy.interpolate import interp1d
from scipy.stats import percentileofscore # For IV Percentile proxy

# --- Constants ---
TRADING_PERIODS_PER_YEAR = 252
MIN_AVG_VOLUME = 1_500_000
IV_RV_THRESHOLD = 0.80 # Threshold for IV/RV ratio (Adjusted from 0.64 for potentially more candidates)
IV_PERCENTILE_THRESHOLD = 30 # Threshold for IV Percentile (<= 30%)
HISTORY_PERIOD = "1y" # Data needed for TAs and historical RV
RV_WINDOW = 30 # Window for Realized Volatility calculation
FAST_SMA = 10
SLOW_SMA = 20
RSI_PERIOD = 14
RSI_OVERSOLD = 30
STOCH_K = 14
STOCH_D = 3
STOCH_SMOOTH_K = 3
STOCH_OVERSOLD = 20
MACD_FAST = 12
MACD_SLOW = 26
MACD_SIGNAL = 9
BBANDS_PERIOD = 20
BBANDS_STD = 2.0
BBANDS_BANDWIDTH_PCT_THRESHOLD = 15 # Bottom percentile for Bollinger Bandwidth squeeze detection


# --- Functions for Calculations ---

def yang_zhang(price_data, window=RV_WINDOW, trading_periods=TRADING_PERIODS_PER_YEAR, return_series=False):
    """
    Calculate realized volatility using the Yang–Zhang method.
    price_data must contain the columns: 'Open', 'High', 'Low', 'Close'
    Can return the full series or just the last value.
    """
    log_ho = np.log(price_data['High'] / price_data['Open'])
    log_lo = np.log(price_data['Low'] / price_data['Open'])
    log_co = np.log(price_data['Close'] / price_data['Open'])
    
    log_oc = np.log(price_data['Open'] / price_data['Close'].shift(1))
    log_oc_sq = log_oc ** 2
    
    log_cc = np.log(price_data['Close'] / price_data['Close'].shift(1))
    log_cc_sq = log_cc ** 2
    
    rs = log_ho * (log_ho - log_co) + log_lo * (log_lo - log_co)
    
    close_vol = log_cc_sq.rolling(window=window, min_periods=window).sum() / (window - 1.0)
    open_vol  = log_oc_sq.rolling(window=window, min_periods=window).sum() / (window - 1.0)
    window_rs = rs.rolling(window=window, min_periods=window).sum() / (window - 1.0)
    
    k = 0.34 / (1.34 + ((window + 1) / (window - 1)))
    
    # Clamp values to avoid sqrt of negative numbers if rs is negative
    variance = open_vol + k * close_vol + (1 - k) * window_rs
    variance = variance.clip(lower=0) # Ensure non-negative variance
    
    result = np.sqrt(variance) * np.sqrt(trading_periods)

    if return_series:
        return result
    else:
        # Ensure we have enough data to calculate the last value
        return result.iloc[-1] if not result.empty and len(result) >= window else np.nan


# --- Helper Functions ---

def get_atm_iv_for_exp(stock, exp_str, underlying_price):
    """
    Retrieve the ATM implied volatility for a given expiration date.
    Pass underlying_price to avoid repeated calls.
    """
    try:
        # Check if options exist for this expiry before fetching
        if exp_str not in stock.options:
            # print(f"DEBUG: Expiry {exp_str} not found in stock.options for {stock.ticker}")
            return None

        chain = stock.option_chain(exp_str)
        calls = chain.calls
        puts = chain.puts
        
        # Check if underlying price is available
        if underlying_price is None or np.isnan(underlying_price):
             print(f"DEBUG: Invalid underlying price for {stock.ticker}")
             return None

        # Ensure strikes are numeric
        calls['strike'] = pd.to_numeric(calls['strike'], errors='coerce')
        puts['strike'] = pd.to_numeric(puts['strike'], errors='coerce')
        calls = calls.dropna(subset=['strike'])
        puts = puts.dropna(subset=['strike'])

        if calls.empty or puts.empty:
            # print(f"DEBUG: Empty calls or puts for {stock.ticker} expiry {exp_str}")
            return None

        # Find the call and put with strike closest to the underlying price.
        calls['abs_diff'] = (calls['strike'] - underlying_price).abs()
        puts['abs_diff'] = (puts['strike'] - underlying_price).abs()
        
        # Handle cases where min() raises error on empty sequence after filtering
        if calls['abs_diff'].isna().all() or puts['abs_diff'].isna().all():
            # print(f"DEBUG: All strikes resulted in NaN differences for {stock.ticker} expiry {exp_str}")
            return None
            
        call_idx = calls['abs_diff'].idxmin()
        put_idx = puts['abs_diff'].idxmin()

        call_iv = calls.loc[call_idx, 'impliedVolatility']
        put_iv = puts.loc[put_idx, 'impliedVolatility']

        # Handle potential missing IV values even for ATM strikes
        if pd.isna(call_iv) or pd.isna(put_iv):
             # Try finding strikes *exactly* matching if possible or nearest available
             # print(f"DEBUG: NaN IV for ATM strike for {stock.ticker} expiry {exp_str}. Trying fallback.")
             # Basic fallback: use whichever is available, or average if both available but one was NaN before
             if pd.isna(call_iv) and not pd.isna(put_iv):
                 atm_iv = put_iv
             elif not pd.isna(call_iv) and pd.isna(put_iv):
                 atm_iv = call_iv
             elif not pd.isna(call_iv) and not pd.isna(put_iv): # Both were valid, average them.
                 atm_iv = (call_iv + put_iv) / 2.0
             else: # Both NaN
                 # print(f"DEBUG: Both call and put IV are NaN for ATM strike {stock.ticker} expiry {exp_str}")
                 return None
        else:
            atm_iv = (call_iv + put_iv) / 2.0
        
        # Basic validation
        if atm_iv is None or np.isnan(atm_iv) or atm_iv <= 0:
            # print(f"DEBUG: Invalid ATM IV calculated ({atm_iv}) for {stock.ticker} expiry {exp_str}")
            return None
            
        return atm_iv

    except Exception as e:
        # print(f"Error fetching/processing option chain for {stock.ticker} expiry {exp_str}: {e}")
        return None


def get_sp500_tickers():
    """
    Scrape S&P 500 tickers from Wikipedia.
    """
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    try:
        tables = pd.read_html(url)
        sp500_table = tables[0]
        # Handle potential changes in column names
        symbol_col = 'Symbol' if 'Symbol' in sp500_table.columns else sp500_table.columns[0] # Assume first col if 'Symbol' isn't there
        tickers = sp500_table[symbol_col].tolist()
        # Replace characters not allowed in yfinance tickers
        tickers = [ticker.replace('.', '-') for ticker in tickers]
         # BF.B -> BF-B, BRK.B -> BRK-B (common examples)
        return tickers
    except Exception as e:
        print(f"Error fetching S&P 500 tickers: {e}")
        # Fallback list if Wikipedia fails
        return ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA', 'TSLA', 'META', 'JPM', 'JNJ', 'V'] # Example subset


def get_current_price(stock_data):
    """
    Retrieve the current (latest available) closing price from historical data.
    """
    if stock_data is None or stock_data.empty:
       return np.nan
    return stock_data['Close'].iloc[-1]

def calculate_technical_indicators(df):
    """ Calculates technical indicators using pandas_ta """
    if df is None or df.empty:
        return df

    # Calculate SMAs
    df.ta.sma(length=FAST_SMA, append=True, col_names=(f'SMA_{FAST_SMA}'))
    df.ta.sma(length=SLOW_SMA, append=True, col_names=(f'SMA_{SLOW_SMA}'))

    # Calculate RSI
    df.ta.rsi(length=RSI_PERIOD, append=True, col_names=(f'RSI_{RSI_PERIOD}'))

    # Calculate Stochastics (%K, %D)
    stoch = df.ta.stoch(k=STOCH_K, d=STOCH_D, smooth_k=STOCH_SMOOTH_K, append=False)
    if stoch is not None and not stoch.empty:
        df[f'STOCHk_{STOCH_K}_{STOCH_D}_{STOCH_SMOOTH_K}'] = stoch.iloc[:, 0] # %K is usually first column
        df[f'STOCHd_{STOCH_K}_{STOCH_D}_{STOCH_SMOOTH_K}'] = stoch.iloc[:, 1] # %D is usually second column

    # Calculate MACD (MACD line, Histogram, Signal line)
    macd = df.ta.macd(fast=MACD_FAST, slow=MACD_SLOW, signal=MACD_SIGNAL, append=False)
    if macd is not None and not macd.empty:
        df[f'MACD_{MACD_FAST}_{MACD_SLOW}_{MACD_SIGNAL}'] = macd.iloc[:, 0] # MACD Line
        df[f'MACDh_{MACD_FAST}_{MACD_SLOW}_{MACD_SIGNAL}'] = macd.iloc[:, 1] # Histogram
        df[f'MACDs_{MACD_FAST}_{MACD_SLOW}_{MACD_SIGNAL}'] = macd.iloc[:, 2] # Signal Line

    # Calculate Bollinger Bands (Upper, Mid, Lower, Bandwidth, %B)
    bbands = df.ta.bbands(length=BBANDS_PERIOD, std=BBANDS_STD, append=False)
    if bbands is not None and not bbands.empty:
        df[f'BBL_{BBANDS_PERIOD}_{BBANDS_STD}'] = bbands.iloc[:, 0] # Lower
        df[f'BBM_{BBANDS_PERIOD}_{BBANDS_STD}'] = bbands.iloc[:, 1] # Mid
        df[f'BBU_{BBANDS_PERIOD}_{BBANDS_STD}'] = bbands.iloc[:, 2] # Upper
        df[f'BBB_{BBANDS_PERIOD}_{BBANDS_STD}'] = bbands.iloc[:, 3] # Bandwidth
        df[f'BBP_{BBANDS_PERIOD}_{BBANDS_STD}'] = bbands.iloc[:, 4] # Percent B

    return df

def check_reversal_signals(df):
    """ Checks the latest data point for bullish reversal signals """
    signals = {}
    triggered_count = 0
    last = df.iloc[-1]
    prev = df.iloc[-2] if len(df) > 1 else None

    # Signal 1: RSI Oversold + Bullish Cross/Tick Up
    rsi_col = f'RSI_{RSI_PERIOD}'
    signals['RSI_Oversold_Cross'] = False
    if rsi_col in df.columns and prev is not None:
        if last[rsi_col] < RSI_OVERSOLD and last[rsi_col] > prev[rsi_col]:
             signals['RSI_Oversold_Cross'] = True
             triggered_count += 1
        # Optional: Also consider crossing up *through* the threshold
        # elif prev[rsi_col] < RSI_OVERSOLD and last[rsi_col] >= RSI_OVERSOLD:
        #     signals['RSI_Oversold_Cross'] = True
        #     triggered_count += 1


    # Signal 2: Stochastic Oversold Bullish Cross
    stoch_k_col = f'STOCHk_{STOCH_K}_{STOCH_D}_{STOCH_SMOOTH_K}'
    stoch_d_col = f'STOCHd_{STOCH_K}_{STOCH_D}_{STOCH_SMOOTH_K}'
    signals['Stochastic_Oversold_Cross'] = False
    if stoch_k_col in df.columns and stoch_d_col in df.columns and prev is not None:
       if (last[stoch_k_col] < STOCH_OVERSOLD and
           last[stoch_d_col] < STOCH_OVERSOLD and
           last[stoch_k_col] > last[stoch_d_col] and # Current K > D
           prev[stoch_k_col] <= prev[stoch_d_col]): # Previous K <= D
            signals['Stochastic_Oversold_Cross'] = True
            triggered_count += 1

    # Signal 3: MACD Histogram Flip to Positive
    macd_h_col = f'MACDh_{MACD_FAST}_{MACD_SLOW}_{MACD_SIGNAL}'
    signals['MACD_Histogram_Flip'] = False
    if macd_h_col in df.columns and prev is not None:
        if last[macd_h_col] > 0 and prev[macd_h_col] <= 0:
            signals['MACD_Histogram_Flip'] = True
            triggered_count += 1

    # Signal 4: Fast SMA Bullish Crossover Slow SMA
    sma_f_col = f'SMA_{FAST_SMA}'
    sma_s_col = f'SMA_{SLOW_SMA}'
    signals['SMA_Bullish_Cross'] = False
    if sma_f_col in df.columns and sma_s_col in df.columns and prev is not None:
        if last[sma_f_col] > last[sma_s_col] and prev[sma_f_col] <= prev[sma_s_col]:
            signals['SMA_Bullish_Cross'] = True
            triggered_count += 1

    # Signal 5: Bollinger Band Squeeze and Breakout (Price closes above Upper Band after low Bandwidth)
    bbu_col = f'BBU_{BBANDS_PERIOD}_{BBANDS_STD}'
    bbb_col = f'BBB_{BBANDS_PERIOD}_{BBANDS_STD}'
    close_col = 'Close'
    signals['Bollinger_Squeeze_Breakout'] = False
    if bbu_col in df.columns and bbb_col in df.columns and close_col in df.columns:
        # Check if bandwidth is low (e.g., in bottom N percentile of its history)
        bandwidth_history = df[bbb_col].dropna()
        if len(bandwidth_history) > BBANDS_PERIOD: # Need some history to compare
            bandwidth_threshold = np.percentile(bandwidth_history, BBANDS_BANDWIDTH_PCT_THRESHOLD)
            # Check if recent bandwidth was low AND current close breaks upper band
            # Look back slightly for low bandwidth condition
            recent_low_bw = (df[bbb_col].rolling(window=5).mean().iloc[-2] < bandwidth_threshold) if len(df)>5 else False # Avg BW over last 5 days (excluding today) was low
            
            if recent_low_bw and last[close_col] > last[bbu_col]:
                signals['Bollinger_Squeeze_Breakout'] = True
                triggered_count += 1

    return signals, triggered_count


# --- Core Screening Function ---

def compute_metrics_and_signals(ticker_symbol):
    """
    For a given ticker, compute volatility metrics, technical indicators,
    check filter conditions, and reversal signals.
    """
    try:
        ticker_symbol = ticker_symbol.strip().upper()
        if not ticker_symbol: return None
        
        stock = yf.Ticker(ticker_symbol)
        
        # 1. Get Historical Data (need enough for TAs and historical RV)
        price_history = stock.history(period=HISTORY_PERIOD)
        if price_history.empty or len(price_history) < max(SLOW_SMA, RV_WINDOW, BBANDS_PERIOD) + 5: # Need buffer
            # print(f"Insufficient price history for {ticker_symbol}")
            return None
            
        # Get current price
        underlying_price = get_current_price(price_history)
        if np.isnan(underlying_price):
             # print(f"Could not determine current price for {ticker_symbol}")
             return None

        # 2. Basic Liquidity Check
        avg_volume = price_history['Volume'].rolling(window=30).mean().iloc[-1]
        pass_volume = avg_volume >= MIN_AVG_VOLUME
        if not pass_volume: # Fail fast if illiquid
             # print(f"Skipping {ticker_symbol} due to low volume ({avg_volume:.0f})")
             return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': 'Low Volume'}


        # 3. Check Options Availability & Dates
        try:
            all_exps = list(stock.options)
            if not all_exps:
                # print(f"No options found for {ticker_symbol}")
                return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': 'No Options'}
        except Exception as e:
             # print(f"Error accessing options dates for {ticker_symbol}: {e}")
             return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': 'Options Error'}

        today = datetime.today().date()
        all_exps_dates = sorted([datetime.strptime(d, "%Y-%m-%d").date() for d in all_exps])
        
        # Find expiration closest to 30 days for IV/RV calculation
        target30_date = min(all_exps_dates, key=lambda d: abs((d - today).days - 30))
        target30_str = target30_date.strftime("%Y-%m-%d")
        dte_target30 = (target30_date - today).days

        # 4. Calculate Volatility Metrics
        #   a) Realized Volatility (Current 30-day)
        rv30 = yang_zhang(price_history, window=RV_WINDOW, return_series=False)
        if np.isnan(rv30) or rv30 == 0:
             # print(f"Could not calculate RV30 for {ticker_symbol}")
             return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': 'RV Calc Error'}

        #   b) Implied Volatility (ATM near 30 days)
        iv_target30 = get_atm_iv_for_exp(stock, target30_str, underlying_price)
        if iv_target30 is None:
             # print(f"Could not get IV30 for {ticker_symbol}")
             return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': 'IV Calc Error'}

        #   c) IV / RV Ratio
        iv30_rv30_ratio = iv_target30 / rv30

        #   d) Historical Realized Volatility (for IV Percentile Proxy)
        historical_rv = yang_zhang(price_history, window=RV_WINDOW, return_series=True).dropna()
        if historical_rv.empty:
            # print(f"Could not calculate historical RV for {ticker_symbol}")
            iv_percentile = np.nan # Cannot calculate percentile
        else:
            # Compare current IV30 to the historical distribution of RV30
            iv_percentile = percentileofscore(historical_rv, iv_target30, kind='strict') # Pct of historical RV values < current IV

        #   e) (Optional) Term Structure Slope (as informational)
        #      Find nearest expiry and one 4-20 days out
        first_expiry = all_exps_dates[0]
        first_exp_str = first_expiry.strftime("%Y-%m-%d")
        dte_first = (first_expiry - today).days
        iv_first = get_atm_iv_for_exp(stock, first_exp_str, underlying_price)

        filtered_exps = [d for d in all_exps_dates if 4 <= (d - today).days <= 20]
        second_expiry = filtered_exps[0] if filtered_exps else None
        ts_slope = np.nan
        dte_second = np.nan
        iv_second = np.nan
        if second_expiry and iv_first is not None:
            second_exp_str = second_expiry.strftime("%Y-%m-%d")
            dte_second = (second_expiry - today).days
            iv_second = get_atm_iv_for_exp(stock, second_exp_str, underlying_price)
            if iv_second is not None and dte_second > dte_first: # Avoid division by zero/negative
                 ts_slope = (iv_second - iv_first) / (dte_second - dte_first)

        # 5. Cheap Volatility Filter (Stage 1)
        pass_cheap_vol_ratio = iv30_rv30_ratio <= IV_RV_THRESHOLD
        pass_cheap_vol_percentile = (not np.isnan(iv_percentile)) and (iv_percentile <= IV_PERCENTILE_THRESHOLD)
        pass_cheap_vol = pass_cheap_vol_ratio or pass_cheap_vol_percentile
        
        if not pass_cheap_vol:
            return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': 'Volatility Not Cheap',
                    'raw': {'avg_volume': avg_volume, 'iv30_rv30': iv30_rv30_ratio, 'iv_percentile': iv_percentile, 'rv30':rv30, 'iv_target30': iv_target30}}

        # 6. Calculate Technical Indicators
        price_history = calculate_technical_indicators(price_history)
        if price_history.empty or price_history.iloc[-1].isna().any(): # Check if latest row has NaNs from TAs
            # print(f"TA calculation failed or resulted in NaNs for {ticker_symbol}")
            return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': 'TA Calc Error'}


        # 7. Reversal Probability Filter (Stage 2)
        reversal_signals, num_reversal_signals = check_reversal_signals(price_history)
        pass_reversal_prob = num_reversal_signals > 0

        if not pass_reversal_prob:
            return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': 'No Reversal Signal',
                     'raw': {'avg_volume': avg_volume, 'iv30_rv30': iv30_rv30_ratio, 'iv_percentile': iv_percentile, 'rv30':rv30, 'iv_target30': iv_target30, 'num_signals': 0}}

        # 8. Passed Both Filters - Calculate Score
        # Score Component 1: Volatility cheapness (lower percentile is better)
        # Normalize percentile to 0-1 range where 1 is best (0th percentile)
        vol_score = (100.0 - iv_percentile) / 100.0 if not np.isnan(iv_percentile) else 0.0
        # If IV percentile failed but ratio passed, give partial score based on ratio? Let's keep it simple for now.

        # Score Component 2: Reversal signals (more is better)
        # Normalize signal count to 0-1 range
        max_signals = 5 # Total number of signal types checked
        signal_score = num_reversal_signals / max_signals

        # Composite Score (simple average, could be weighted)
        composite_score = (vol_score + signal_score) / 2.0

        # 9. Calculate Expected Move (Informational) - Use near-term ATM straddle
        expected_move = "N/A"
        if iv_first is not None:
             try:
                 chain_first = stock.option_chain(first_exp_str)
                 calls = chain_first.calls
                 puts = chain_first.puts
                 calls['strike'] = pd.to_numeric(calls['strike'], errors='coerce')
                 puts['strike'] = pd.to_numeric(puts['strike'], errors='coerce')
                 calls = calls.dropna(subset=['strike'])
                 puts = puts.dropna(subset=['strike'])

                 if not calls.empty and not puts.empty:
                     calls['abs_diff'] = (calls['strike'] - underlying_price).abs()
                     puts['abs_diff'] = (puts['strike'] - underlying_price).abs()
                     call_idx = calls['abs_diff'].idxmin()
                     put_idx = puts['abs_diff'].idxmin()

                     # Use mid-point of bid/ask for straddle price
                     call_bid = calls.loc[call_idx, 'bid']
                     call_ask = calls.loc[call_idx, 'ask']
                     put_bid = puts.loc[put_idx, 'bid']
                     put_ask = puts.loc[put_idx, 'ask']
                     
                     # Handle zero bid/ask often seen for some options
                     call_mid = (call_bid + call_ask) / 2.0 if call_bid > 0 and call_ask > 0 else calls.loc[call_idx, 'lastPrice']
                     put_mid = (put_bid + put_ask) / 2.0 if put_bid > 0 and put_ask > 0 else puts.loc[put_idx, 'lastPrice']

                     if pd.notna(call_mid) and pd.notna(put_mid) and underlying_price > 0:
                         straddle = call_mid + put_mid
                         expected_move = f"{round(straddle / underlying_price * 100, 2)}%"
                     else: straddle = np.nan
                 else: straddle = np.nan
             except Exception:
                 straddle = np.nan # Ignore errors in expected move calc
                 expected_move = "Error"


        # Prepare results dictionary
        return {
            'ticker': ticker_symbol,
            'pass_filters': True,
            'score': composite_score,
            'vol_score': vol_score,
            'signal_score': signal_score,
            'num_reversal_signals': num_reversal_signals,
            'reversal_signals': reversal_signals, # Dict of True/False for each signal
            'iv_percentile': iv_percentile,
            'iv30_rv30_ratio': iv30_rv30_ratio,
            'expected_move': expected_move,
            'raw': {
                'avg_volume': avg_volume,
                'iv_target30': iv_target30,
                'rv30': rv30,
                'ts_slope': ts_slope,
                'underlying_price': underlying_price,
                # Add last values of key indicators for context
                'RSI': price_history[f'RSI_{RSI_PERIOD}'].iloc[-1],
                'STOCH_K': price_history[f'STOCHk_{STOCH_K}_{STOCH_D}_{STOCH_SMOOTH_K}'].iloc[-1],
                'MACD_Hist': price_history[f'MACDh_{MACD_FAST}_{MACD_SLOW}_{MACD_SIGNAL}'].iloc[-1],
                'SMA_Fast': price_history[f'SMA_{FAST_SMA}'].iloc[-1],
                'SMA_Slow': price_history[f'SMA_{SLOW_SMA}'].iloc[-1],
                'BB_PctB': price_history[f'BBP_{BBANDS_PERIOD}_{BBANDS_STD}'].iloc[-1],
                'BB_Width': price_history[f'BBB_{BBANDS_PERIOD}_{BBANDS_STD}'].iloc[-1],
            }
        }

    except Exception as e:
        print(f"ERROR processing {ticker_symbol}: {e}")
        # In production, log the error details (traceback)
        import traceback
        # print(traceback.format_exc())
        return {'ticker': ticker_symbol, 'pass_filters': False, 'reason': f'Unhandled Error: {e}'}

# --- Main Screening Script ---

def main():
    tickers_to_screen = get_sp500_tickers()
    # Optional: Use a smaller list for testing
    # tickers_to_screen = ['AAPL', 'MSFT', 'GOOGL', 'NVDA', 'AMD', 'TSLA', 'SPY', 'QQQ', 'IWM', 'NFLX', 'COIN', 'AMC', 'GME'] # Example list
    
    results = []
    failed_tickers = []

    print(f"Screening {len(tickers_to_screen)} tickers based on Volatility and Reversal Signals...\n")
    
    count = 0
    for ticker in tickers_to_screen:
        count += 1
        print(f"Processing {ticker}... ({count}/{len(tickers_to_screen)})")
        
        metrics = compute_metrics_and_signals(ticker)

        if metrics is None:
            print(f"  Data error or insufficient data for {ticker}. Skipping.\n")
            failed_tickers.append({'ticker': ticker, 'reason': 'Data Error/Insufficient'})
            continue
            
        if metrics['pass_filters']:
            results.append(metrics)
            print(f"  >>> PASSED Filters: {ticker} <<<")
            print(f"      Score: {metrics['score']:.3f} (Vol: {metrics['vol_score']:.2f}, Signal: {metrics['signal_score']:.2f})")
            print(f"      IV Pctile: {metrics['iv_percentile']:.1f}%, IV/RV Ratio: {metrics['iv30_rv30_ratio']:.2f}")
            print(f"      Signals ({metrics['num_reversal_signals']}): {[sig for sig, triggered in metrics['reversal_signals'].items() if triggered]}")
            print(f"      Exp. Move: {metrics['expected_move']}")
            print(f"      Price: {metrics['raw']['underlying_price']:.2f}, Vol: {metrics['raw']['avg_volume']:.0f}\n")
        else:
            failed_tickers.append(metrics) # Store failure reason
            print(f"  Skipped {ticker}: {metrics.get('reason', 'Unknown')}\n")

    # Sort the survivors by score (highest first)
    results.sort(key=lambda x: x['score'], reverse=True)

    # Final summary:
    print("\n" + "="*50)
    print("Final Screening Results:")
    print("="*50 + "\n")

    if not results:
        print("No tickers passed both the Cheap Volatility and Reversal Probability filters.")
    else:
        print(f"--- {len(results)} Tickers Passed Filters (Ranked by Score) ---")
        for i, result in enumerate(results):
            print(f"{i+1}. {result['ticker']}")
            print(f"   Score: {result['score']:.3f} (Vol: {result['vol_score']:.2f}, Signal: {result['signal_score']:.2f})")
            print(f"   IV Pct (proxy): {result['iv_percentile']:.1f}%, IV/RV Ratio: {result['iv30_rv30_ratio']:.2f}")
            print(f"   Signals ({result['num_reversal_signals']}): {[sig for sig, triggered in result['reversal_signals'].items() if triggered]}")
            print(f"   Exp. Move: {result['expected_move']}")
            print(f"   Price: {result['raw']['underlying_price']:.2f}, Avg Vol: {result['raw']['avg_volume']:.0f}")
            # Optional: Print more raw data if needed
            # print(f"   Raw IV30: {result['raw']['iv_target30']:.3f}, Raw RV30: {result['raw']['rv30']:.3f}")
            # print(f"   RSI: {result['raw']['RSI']:.1f}, StochK: {result['raw']['STOCH_K']:.1f}, MACD Hist: {result['raw']['MACD_Hist']:.3f}")
            print("-" * 20)

    # Optional: Print summary of failures
    print(f"\n--- {len(failed_tickers)} Tickers Failed Filters ---")
    # Count failure reasons
    from collections import Counter
    failure_counts = Counter(item.get('reason', 'Unknown') for item in failed_tickers)
    print("Failure Reasons:")
    for reason, count in failure_counts.most_common():
        print(f"  - {reason}: {count}")

    print("\n" + "="*50)
    print("Screening Complete.")
    print("="*50)
    
if __name__ == "__main__":
    main()
# Out:
# Screening 503 tickers based on Volatility and Reversal Signals...
#
# Processing MMM... (1/503)
#   Skipped MMM: Volatility Not Cheap
#
# Processing AOS... (2/503)
#   Skipped AOS: Volatility Not Cheap
#
# Processing ABT... (3/503)
#   Skipped ABT: No Reversal Signal
#
# Processing ABBV... (4/503)
#   Skipped ABBV: No Reversal Signal
#
# Processing ACN... (5/503)
#   Skipped ACN: No Reversal Signal
#
# Processing ADBE... (6/503)
#   >>> PASSED Filters: ADBE <<<
#       Score: 0.361 (Vol: 0.52, Signal: 0.20)
#       IV Pctile: 47.7%, IV/RV Ratio: 0.63
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 0.94%
#       Price: 349.44, Vol: 4819225
#
# Processing AMD... (7/503)
#   Skipped AMD: Volatility Not Cheap
#
# Processing AES... (8/503)
#   Skipped AES: Volatility Not Cheap
#
# Processing AFL... (9/503)
#   Skipped AFL: Volatility Not Cheap
#
# Processing A... (10/503)
#   Skipped A: Volatility Not Cheap
#
# Processing APD... (11/503)
#   Skipped APD: Low Volume
#
# Processing ABNB... (12/503)
#   Skipped ABNB: Volatility Not Cheap
#
# Processing AKAM... (13/503)
#   Skipped AKAM: Volatility Not Cheap
#
# Processing ALB... (14/503)
#   Skipped ALB: Volatility Not Cheap
#
# Processing ARE... (15/503)
#   Skipped ARE: Volatility Not Cheap
#
# Processing ALGN... (16/503)
#   Skipped ALGN: Low Volume
#
# Processing ALLE... (17/503)
#   Skipped ALLE: Low Volume
#
# Processing LNT... (18/503)
#   Skipped LNT: Volatility Not Cheap
#
# Processing ALL... (19/503)
#   Skipped ALL: Volatility Not Cheap
#
# Processing GOOGL... (20/503)
#   Skipped GOOGL: Volatility Not Cheap
#
# Processing GOOG... (21/503)
#   Skipped GOOG: Volatility Not Cheap
#
# Processing MO... (22/503)
#   Skipped MO: Volatility Not Cheap
#
# Processing AMZN... (23/503)
#   Skipped AMZN: No Reversal Signal
#
# Processing AMCR... (24/503)
#   Skipped AMCR: Volatility Not Cheap
#
# Processing AEE... (25/503)
#   Skipped AEE: Volatility Not Cheap
#
# Processing AEP... (26/503)
#   Skipped AEP: Volatility Not Cheap
#
# Processing AXP... (27/503)
#   Skipped AXP: No Reversal Signal
#
# Processing AIG... (28/503)
#   Skipped AIG: Volatility Not Cheap
#
# Processing AMT... (29/503)
#   Skipped AMT: Volatility Not Cheap
#
# Processing AWK... (30/503)
#   Skipped AWK: No Reversal Signal
#
# Processing AMP... (31/503)
#   Skipped AMP: Low Volume
#
# Processing AME... (32/503)
#   Skipped AME: Volatility Not Cheap
#
# Processing AMGN... (33/503)
#   Skipped AMGN: Volatility Not Cheap
#
# Processing APH... (34/503)
#   Skipped APH: Volatility Not Cheap
#
# Processing ADI... (35/503)
#   Skipped ADI: No Reversal Signal
#
# Processing ANSS... (36/503)
#   Skipped ANSS: Low Volume
#
# Processing AON... (37/503)
#   Skipped AON: Low Volume
#
# Processing APA... (38/503)
#   Skipped APA: Volatility Not Cheap
#
# Processing APO... (39/503)
#   Skipped APO: No Reversal Signal
#
# Processing AAPL... (40/503)
#   Skipped AAPL: No Reversal Signal
#
# Processing AMAT... (41/503)
#   Skipped AMAT: No Reversal Signal
#
# Processing APTV... (42/503)
#   Skipped APTV: Volatility Not Cheap
#
# Processing ACGL... (43/503)
#   Skipped ACGL: Volatility Not Cheap
#
# Processing ADM... (44/503)
#   Skipped ADM: Volatility Not Cheap
#
# Processing ANET... (45/503)
#   Skipped ANET: Volatility Not Cheap
#
# Processing AJG... (46/503)
#   Skipped AJG: Volatility Not Cheap
#
# Processing AIZ... (47/503)
#   Skipped AIZ: Low Volume
#
# Processing T... (48/503)
#   Skipped T: Volatility Not Cheap
#
# Processing ATO... (49/503)
#   Skipped ATO: Low Volume
#
# Processing ADSK... (50/503)
#   Skipped ADSK: No Reversal Signal
#
# Processing ADP... (51/503)
#   Skipped ADP: Volatility Not Cheap
#
# Processing AZO... (52/503)
#   Skipped AZO: Low Volume
#
# Processing AVB... (53/503)
#   Skipped AVB: Low Volume
#
# Processing AVY... (54/503)
#   Skipped AVY: Low Volume
#
# Processing AXON... (55/503)
#   Skipped AXON: Low Volume
#
# Processing BKR... (56/503)
#   Skipped BKR: No Reversal Signal
#
# Processing BALL... (57/503)
#   Skipped BALL: Volatility Not Cheap
#
# Processing BAC... (58/503)
#   >>> PASSED Filters: BAC <<<
#       Score: 0.195 (Vol: 0.19, Signal: 0.20)
#       IV Pctile: 81.1%, IV/RV Ratio: 0.56
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 0.92%
#       Price: 37.51, Vol: 57066426
#
# Processing BAX... (59/503)
#   Skipped BAX: Volatility Not Cheap
#
# Processing BDX... (60/503)
#   Skipped BDX: Volatility Not Cheap
#
# Processing BRK-B... (61/503)
#   Skipped BRK-B: No Reversal Signal
#
# Processing BBY... (62/503)
#   Skipped BBY: No Reversal Signal
#
# Processing TECH... (63/503)
#   Skipped TECH: Volatility Not Cheap
#
# Processing BIIB... (64/503)
#   Skipped BIIB: Volatility Not Cheap
#
# Processing BLK... (65/503)
#   Skipped BLK: Low Volume
#
# Processing BX... (66/503)
#   Skipped BX: No Reversal Signal
#
# Processing BK... (67/503)
#   Skipped BK: No Reversal Signal
#
# Processing BA... (68/503)
#   Skipped BA: No Reversal Signal
#
# Processing BKNG... (69/503)
#   Skipped BKNG: Low Volume
#
# Processing BSX... (70/503)
#   >>> PASSED Filters: BSX <<<
#       Score: 0.123 (Vol: 0.05, Signal: 0.20)
#       IV Pctile: 95.5%, IV/RV Ratio: 0.75
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 1.43%
#       Price: 95.46, Vol: 9491612
#
# Processing BMY... (71/503)
#   Skipped BMY: Volatility Not Cheap
#
# Processing AVGO... (72/503)
#   Skipped AVGO: No Reversal Signal
#
# Processing BR... (73/503)
#   Skipped BR: Low Volume
#
# Processing BRO... (74/503)
#   Skipped BRO: Volatility Not Cheap
#
# Processing BF-B... (75/503)
#   Skipped BF-B: No Reversal Signal
#
# Processing BLDR... (76/503)
#   Skipped BLDR: Volatility Not Cheap
#
# Processing BG... (77/503)
#   Skipped BG: Volatility Not Cheap
#
# Processing BXP... (78/503)
#   Skipped BXP: Volatility Not Cheap
#
# Processing CHRW... (79/503)
#   Skipped CHRW: Volatility Not Cheap
#
# Processing CDNS... (80/503)
#   Skipped CDNS: Volatility Not Cheap
#
# Processing CZR... (81/503)
#   Skipped CZR: Volatility Not Cheap
#
# Processing CPT... (82/503)
#   Skipped CPT: Low Volume
#
# Processing CPB... (83/503)
#   Skipped CPB: No Reversal Signal
#
# Processing COF... (84/503)
#   >>> PASSED Filters: COF <<<
#       Score: 0.174 (Vol: 0.15, Signal: 0.20)
#       IV Pctile: 85.1%, IV/RV Ratio: 0.70
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 1.44%
#       Price: 162.64, Vol: 5542021
#
# Processing CAH... (85/503)
#   Skipped CAH: Volatility Not Cheap
#
# Processing KMX... (86/503)
#   Skipped KMX: No Reversal Signal
#
# Processing CCL... (87/503)
#   Skipped CCL: No Reversal Signal
#
# Processing CARR... (88/503)
#   Skipped CARR: Volatility Not Cheap
#
# Processing CAT... (89/503)
#   Skipped CAT: No Reversal Signal
#
# Processing CBOE... (90/503)
#   Skipped CBOE: Low Volume
#
# Processing CBRE... (91/503)
#   Skipped CBRE: Volatility Not Cheap
#
# Processing CDW... (92/503)
#   Skipped CDW: Volatility Not Cheap
#
# Processing COR... (93/503)
#   Skipped COR: Volatility Not Cheap
#
# Processing CNC... (94/503)
#   Skipped CNC: Volatility Not Cheap
#
# Processing CNP... (95/503)
#   Skipped CNP: Volatility Not Cheap
#
# Processing CF... (96/503)
#   Skipped CF: Volatility Not Cheap
#
# Processing CRL... (97/503)
#   Skipped CRL: Volatility Not Cheap
#
# Processing SCHW... (98/503)
#   Skipped SCHW: No Reversal Signal
#
# Processing CHTR... (99/503)
#   Skipped CHTR: Low Volume
#
# Processing CVX... (100/503)
#   Skipped CVX: No Reversal Signal
#
# Processing CMG... (101/503)
#   Skipped CMG: Volatility Not Cheap
#
# Processing CB... (102/503)
#   Skipped CB: Volatility Not Cheap
#
# Processing CHD... (103/503)
#   Skipped CHD: Volatility Not Cheap
#
# Processing CI... (104/503)
#   Skipped CI: Volatility Not Cheap
#
# Processing CINF... (105/503)
#   Skipped CINF: Low Volume
#
# Processing CTAS... (106/503)
#   Skipped CTAS: No Reversal Signal
#
# Processing CSCO... (107/503)
#   Skipped CSCO: Volatility Not Cheap
#
# Processing C... (108/503)
#   >>> PASSED Filters: C <<<
#       Score: 0.199 (Vol: 0.20, Signal: 0.20)
#       IV Pctile: 80.2%, IV/RV Ratio: 0.60
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 0.98%
#       Price: 62.88, Vol: 20559104
#
# Processing CFG... (109/503)
#   Skipped CFG: No Reversal Signal
#
# Processing CLX... (110/503)
#   Skipped CLX: Low Volume
#
# Processing CME... (111/503)
#   Skipped CME: Volatility Not Cheap
#
# Processing CMS... (112/503)
#   Skipped CMS: Volatility Not Cheap
#
# Processing KO... (113/503)
#   Skipped KO: No Reversal Signal
#
# Processing CTSH... (114/503)
#   Skipped CTSH: Volatility Not Cheap
#
# Processing CL... (115/503)
#   Skipped CL: Volatility Not Cheap
#
# Processing CMCSA... (116/503)
#   Skipped CMCSA: Volatility Not Cheap
#
# Processing CAG... (117/503)
#   Skipped CAG: Volatility Not Cheap
#
# Processing COP... (118/503)
#   Skipped COP: No Reversal Signal
#
# Processing ED... (119/503)
#   >>> PASSED Filters: ED <<<
#       Score: 0.179 (Vol: 0.16, Signal: 0.20)
#       IV Pctile: 84.2%, IV/RV Ratio: 0.78
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 2.68%
#       Price: 113.04, Vol: 2949530
#
# Processing STZ... (120/503)
#   Skipped STZ: No Reversal Signal
#
# Processing CEG... (121/503)
#   Skipped CEG: No Reversal Signal
#
# Processing COO... (122/503)
#   Skipped COO: Volatility Not Cheap
#
# Processing CPRT... (123/503)
#   Skipped CPRT: Volatility Not Cheap
#
# Processing GLW... (124/503)
#   Skipped GLW: Volatility Not Cheap
#
# Processing CPAY... (125/503)
#   Skipped CPAY: Low Volume
#
# Processing CTVA... (126/503)
#   Skipped CTVA: Volatility Not Cheap
#
# Processing CSGP... (127/503)
#   Skipped CSGP: Volatility Not Cheap
#
# Processing COST... (128/503)
#   Skipped COST: No Reversal Signal
#
# Processing CTRA... (129/503)
#   Skipped CTRA: Volatility Not Cheap
#
# Processing CRWD... (130/503)
#   Skipped CRWD: No Reversal Signal
#
# Processing CCI... (131/503)
#   Skipped CCI: No Reversal Signal
#
# Processing CSX... (132/503)
#   Skipped CSX: Volatility Not Cheap
#
# Processing CMI... (133/503)
#   Skipped CMI: Low Volume
#
# Processing CVS... (134/503)
#   Skipped CVS: Volatility Not Cheap
#
# Processing DHR... (135/503)
#   Skipped DHR: Volatility Not Cheap
#
# Processing DRI... (136/503)
#   Skipped DRI: Low Volume
#
# Processing DVA... (137/503)
#   Skipped DVA: Low Volume
#
# Processing DAY... (138/503)
#   Skipped DAY: Volatility Not Cheap
#
# Processing DECK... (139/503)
#   Skipped DECK: No Reversal Signal
#
# Processing DE... (140/503)
#   Skipped DE: Volatility Not Cheap
#
# Processing DELL... (141/503)
#   Skipped DELL: No Reversal Signal
#
# Processing DAL... (142/503)
#   Skipped DAL: No Reversal Signal
#
# Processing DVN... (143/503)
#   Skipped DVN: No Reversal Signal
#
# Processing DXCM... (144/503)
#   Skipped DXCM: Volatility Not Cheap
#
# Processing FANG... (145/503)
#   Skipped FANG: No Reversal Signal
#
# Processing DLR... (146/503)
#   Skipped DLR: Volatility Not Cheap
#
# Processing DFS... (147/503)
#   Skipped DFS: No Reversal Signal
#
# Processing DG... (148/503)
#   Skipped DG: No Reversal Signal
#
# Processing DLTR... (149/503)
#   >>> PASSED Filters: DLTR <<<
#       Score: 0.244 (Vol: 0.29, Signal: 0.20)
#       IV Pctile: 71.2%, IV/RV Ratio: 0.60
#       Signals (1): ['SMA_Bullish_Cross']
#       Exp. Move: 1.48%
#       Price: 77.91, Vol: 6718931
#
# Processing D... (150/503)
#   Skipped D: Volatility Not Cheap
#
# Processing DPZ... (151/503)
#   Skipped DPZ: Low Volume
#
# Processing DASH... (152/503)
#   Skipped DASH: Volatility Not Cheap
#
# Processing DOV... (153/503)
#   Skipped DOV: Low Volume
#
# Processing DOW... (154/503)
#   Skipped DOW: Volatility Not Cheap
#
# Processing DHI... (155/503)
#   Skipped DHI: Volatility Not Cheap
#
# Processing DTE... (156/503)
#   Skipped DTE: Volatility Not Cheap
#
# Processing DUK... (157/503)
#   Skipped DUK: Volatility Not Cheap
#
# Processing DD... (158/503)
#   Skipped DD: No Reversal Signal
#
# Processing EMN... (159/503)
#   Skipped EMN: Low Volume
#
# Processing ETN... (160/503)
#   Skipped ETN: No Reversal Signal
#
# Processing EBAY... (161/503)
#   Skipped EBAY: Volatility Not Cheap
#
# Processing ECL... (162/503)
#   Skipped ECL: Volatility Not Cheap
#
# Processing EIX... (163/503)
#   Skipped EIX: Volatility Not Cheap
#
# Processing EW... (164/503)
#   Skipped EW: Volatility Not Cheap
#
# Processing EA... (165/503)
#   Skipped EA: Volatility Not Cheap
#
# Processing ELV... (166/503)
#   Skipped ELV: No Reversal Signal
#
# Processing EMR... (167/503)
#   >>> PASSED Filters: EMR <<<
#       Score: 0.123 (Vol: 0.05, Signal: 0.20)
#       IV Pctile: 95.5%, IV/RV Ratio: 0.78
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 2.37%
#       Price: 100.17, Vol: 3542193
#
# Processing ENPH... (168/503)
#   Skipped ENPH: Volatility Not Cheap
#
# Processing ETR... (169/503)
#   Skipped ETR: Volatility Not Cheap
#
# Processing EOG... (170/503)
#   Skipped EOG: No Reversal Signal
#
# Processing EPAM... (171/503)
#   Skipped EPAM: Low Volume
#
# Processing EQT... (172/503)
#   >>> PASSED Filters: EQT <<<
#       Score: 0.123 (Vol: 0.05, Signal: 0.20)
#       IV Pctile: 95.5%, IV/RV Ratio: 0.79
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 2.1%
#       Price: 51.46, Vol: 8299806
#
# Processing EFX... (173/503)
#   Skipped EFX: Low Volume
#
# Processing EQIX... (174/503)
#   Skipped EQIX: Low Volume
#
# Processing EQR... (175/503)
#   Skipped EQR: Volatility Not Cheap
#
# Processing ERIE... (176/503)
#   Skipped ERIE: Low Volume
#
# Processing ESS... (177/503)
#   Skipped ESS: Low Volume
#
# Processing EL... (178/503)
#   Skipped EL: Volatility Not Cheap
#
# Processing EG... (179/503)
#   Skipped EG: Low Volume
#
# Processing EVRG... (180/503)
#   Skipped EVRG: Volatility Not Cheap
#
# Processing ES... (181/503)
#   Skipped ES: Volatility Not Cheap
#
# Processing EXC... (182/503)
#   Skipped EXC: Volatility Not Cheap
#
# Processing EXE... (183/503)
#   Skipped EXE: No Reversal Signal
#
# Processing EXPE... (184/503)
#   Skipped EXPE: Volatility Not Cheap
#
# Processing EXPD... (185/503)
#   Skipped EXPD: Volatility Not Cheap
#
# Processing EXR... (186/503)
#   Skipped EXR: Low Volume
#
# Processing XOM... (187/503)
#   Skipped XOM: Volatility Not Cheap
#
# Processing FFIV... (188/503)
#   Skipped FFIV: Low Volume
#
# Processing FDS... (189/503)
#   Skipped FDS: Low Volume
#
# Processing FICO... (190/503)
#   Skipped FICO: Low Volume
#
# Processing FAST... (191/503)
#   Skipped FAST: No Reversal Signal
#
# Processing FRT... (192/503)
#   Skipped FRT: Low Volume
#
# Processing FDX... (193/503)
#   Skipped FDX: No Reversal Signal
#
# Processing FIS... (194/503)
#   Skipped FIS: Volatility Not Cheap
#
# Processing FITB... (195/503)
#   Skipped FITB: No Reversal Signal
#
# Processing FSLR... (196/503)
#   Skipped FSLR: Volatility Not Cheap
#
# Processing FE... (197/503)
#   Skipped FE: Volatility Not Cheap
#
# Processing FI... (198/503)
#   Skipped FI: Volatility Not Cheap
#
# Processing F... (199/503)
#   Skipped F: Volatility Not Cheap
#
# Processing FTNT... (200/503)
#   Skipped FTNT: Volatility Not Cheap
#
# Processing FTV... (201/503)
#   Skipped FTV: Volatility Not Cheap
#
# Processing FOXA... (202/503)
#   Skipped FOXA: Volatility Not Cheap
#
# Processing FOX... (203/503)
#   Skipped FOX: Low Volume
#
# Processing BEN... (204/503)
#   Skipped BEN: Volatility Not Cheap
#
# Processing FCX... (205/503)
#   Skipped FCX: No Reversal Signal
#
# Processing GRMN... (206/503)
#   Skipped GRMN: Low Volume
#
# Processing IT... (207/503)
#   Skipped IT: Low Volume
#
# Processing GE... (208/503)
#   Skipped GE: No Reversal Signal
#
# Processing GEHC... (209/503)
#   Skipped GEHC: No Reversal Signal
#
# Processing GEV... (210/503)
#   Skipped GEV: No Reversal Signal
#
# Processing GEN... (211/503)
#   Skipped GEN: Volatility Not Cheap
#
# Processing GNRC... (212/503)
#   Skipped GNRC: Low Volume
#
# Processing GD... (213/503)
#   Skipped GD: Volatility Not Cheap
#
# Processing GIS... (214/503)
#   Skipped GIS: No Reversal Signal
#
# Processing GM... (215/503)
#   Skipped GM: Volatility Not Cheap
#
# Processing GPC... (216/503)
#   Skipped GPC: Volatility Not Cheap
#
# Processing GILD... (217/503)
#   Skipped GILD: Volatility Not Cheap
#
# Processing GPN... (218/503)
#   Skipped GPN: No Reversal Signal
#
# Processing GL... (219/503)
#   Skipped GL: Low Volume
#
# Processing GDDY... (220/503)
#   Skipped GDDY: Volatility Not Cheap
#
# Processing GS... (221/503)
#   Skipped GS: No Reversal Signal
#
# Processing HAL... (222/503)
#   Skipped HAL: No Reversal Signal
#
# Processing HIG... (223/503)
#   Skipped HIG: Volatility Not Cheap
#
# Processing HAS... (224/503)
#   Skipped HAS: Volatility Not Cheap
#
# Processing HCA... (225/503)
#   Skipped HCA: Volatility Not Cheap
#
# Processing DOC... (226/503)
#   Skipped DOC: Volatility Not Cheap
#
# Processing HSIC... (227/503)
#   Skipped HSIC: Volatility Not Cheap
#
# Processing HSY... (228/503)
#   Skipped HSY: Volatility Not Cheap
#
# Processing HES... (229/503)
#   >>> PASSED Filters: HES <<<
#       Score: 0.120 (Vol: 0.04, Signal: 0.20)
#       IV Pctile: 95.9%, IV/RV Ratio: 0.79
#       Signals (1): ['Stochastic_Oversold_Cross']
#       Exp. Move: 4.38%
#       Price: 131.94, Vol: 2180681
#
# Processing HPE... (230/503)
#   Skipped HPE: No Reversal Signal
#
# Processing HLT... (231/503)
#   Skipped HLT: Volatility Not Cheap
#
# Processing HOLX... (232/503)
#   Skipped HOLX: Volatility Not Cheap
#
# Processing HD... (233/503)
#   Skipped HD: No Reversal Signal
#
# Processing HON... (234/503)
#   Skipped HON: Volatility Not Cheap
#
# Processing HRL... (235/503)
#   Skipped HRL: No Reversal Signal
#
# Processing HST... (236/503)
#   Skipped HST: Volatility Not Cheap
#
# Processing HWM... (237/503)
#   Skipped HWM: Volatility Not Cheap
#
# Processing HPQ... (238/503)
#   >>> PASSED Filters: HPQ <<<
#       Score: 0.258 (Vol: 0.32, Signal: 0.20)
#       IV Pctile: 68.5%, IV/RV Ratio: 0.66
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 1.62%
#       Price: 23.71, Vol: 10266530
#
# Processing HUBB... (239/503)
#   Skipped HUBB: Low Volume
#
# Processing HUM... (240/503)
#   Skipped HUM: Volatility Not Cheap
#
# Processing HBAN... (241/503)
#   >>> PASSED Filters: HBAN <<<
#       Score: 0.123 (Vol: 0.05, Signal: 0.20)
#       IV Pctile: 95.5%, IV/RV Ratio: 0.67
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 2.47%
#       Price: 13.77, Vol: 25465979
#
# Processing HII... (242/503)
#   Skipped HII: Low Volume
#
# Processing IBM... (243/503)
#   Skipped IBM: Volatility Not Cheap
#
# Processing IEX... (244/503)
#   Skipped IEX: Low Volume
#
# Processing IDXX... (245/503)
#   Skipped IDXX: Low Volume
#
# Processing ITW... (246/503)
#   Skipped ITW: Low Volume
#
# Processing INCY... (247/503)
#   Skipped INCY: Volatility Not Cheap
#
# Processing IR... (248/503)
#   Skipped IR: Volatility Not Cheap
#
# Processing PODD... (249/503)
#   Skipped PODD: Low Volume
#
# Processing INTC... (250/503)
#   Skipped INTC: No Reversal Signal
#
# Processing ICE... (251/503)
#   Skipped ICE: Volatility Not Cheap
#
# Processing IFF... (252/503)
#   Skipped IFF: Volatility Not Cheap
#
# Processing IP... (253/503)
#   Skipped IP: No Reversal Signal
#
# Processing IPG... (254/503)
#   Skipped IPG: Volatility Not Cheap
#
# Processing INTU... (255/503)
#   Skipped INTU: Volatility Not Cheap
#
# Processing ISRG... (256/503)
#   Skipped ISRG: No Reversal Signal
#
# Processing IVZ... (257/503)
#   Skipped IVZ: No Reversal Signal
#
# Processing INVH... (258/503)
#   Skipped INVH: Volatility Not Cheap
#
# Processing IQV... (259/503)
#   Skipped IQV: Volatility Not Cheap
#
# Processing IRM... (260/503)
#   Skipped IRM: Volatility Not Cheap
#
# Processing JBHT... (261/503)
#   Skipped JBHT: Low Volume
#
# Processing JBL... (262/503)
#   Skipped JBL: No Reversal Signal
#
# Processing JKHY... (263/503)
#   Skipped JKHY: Low Volume
#
# Processing J... (264/503)
#   Skipped J: Low Volume
#
# Processing JNJ... (265/503)
#   >>> PASSED Filters: JNJ <<<
#       Score: 0.192 (Vol: 0.18, Signal: 0.20)
#       IV Pctile: 81.5%, IV/RV Ratio: 0.57
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 0.55%
#       Price: 158.09, Vol: 10622624
#
# Processing JCI... (266/503)
#   Skipped JCI: Volatility Not Cheap
#
# Processing JPM... (267/503)
#   Skipped JPM: No Reversal Signal
#
# Processing JNPR... (268/503)
#   Skipped JNPR: Volatility Not Cheap
#
# Processing K... (269/503)
#   Skipped K: Volatility Not Cheap
#
# Processing KVUE... (270/503)
#   Skipped KVUE: Volatility Not Cheap
#
# Processing KDP... (271/503)
#   Skipped KDP: Volatility Not Cheap
#
# Processing KEY... (272/503)
#   >>> PASSED Filters: KEY <<<
#       Score: 0.192 (Vol: 0.18, Signal: 0.20)
#       IV Pctile: 81.5%, IV/RV Ratio: 0.70
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 1.29%
#       Price: 14.40, Vol: 18250440
#
# Processing KEYS... (273/503)
#   Skipped KEYS: Low Volume
#
# Processing KMB... (274/503)
#   Skipped KMB: Volatility Not Cheap
#
# Processing KIM... (275/503)
#   Skipped KIM: No Reversal Signal
#
# Processing KMI... (276/503)
#   >>> PASSED Filters: KMI <<<
#       Score: 0.136 (Vol: 0.07, Signal: 0.20)
#       IV Pctile: 92.8%, IV/RV Ratio: 0.75
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 1.38%
#       Price: 27.44, Vol: 13557177
#
# Processing KKR... (277/503)
#   Skipped KKR: No Reversal Signal
#
# Processing KLAC... (278/503)
#   Skipped KLAC: Low Volume
#
# Processing KHC... (279/503)
#   Skipped KHC: Volatility Not Cheap
#
# Processing KR... (280/503)
#   Skipped KR: No Reversal Signal
#
# Processing LHX... (281/503)
#   Skipped LHX: Low Volume
#
# Processing LH... (282/503)
#   Skipped LH: Low Volume
#
# Processing LRCX... (283/503)
#   Skipped LRCX: Volatility Not Cheap
#
# Processing LW... (284/503)
#   Skipped LW: No Reversal Signal
#
# Processing LVS... (285/503)
#   Skipped LVS: Volatility Not Cheap
#
# Processing LDOS... (286/503)
#   Skipped LDOS: Volatility Not Cheap
#
# Processing LEN... (287/503)
#   Skipped LEN: No Reversal Signal
#
# Processing LII... (288/503)
#   Skipped LII: Low Volume
#
# Processing LLY... (289/503)
#   >>> PASSED Filters: LLY <<<
#       Score: 0.260 (Vol: 0.32, Signal: 0.20)
#       IV Pctile: 68.0%, IV/RV Ratio: 0.64
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 0.95%
#       Price: 839.11, Vol: 3781721
#
# Processing LIN... (290/503)
#   Skipped LIN: Volatility Not Cheap
#
# Processing LYV... (291/503)
#   Skipped LYV: Volatility Not Cheap
#
# Processing LKQ... (292/503)
#   Skipped LKQ: Volatility Not Cheap
#
# Processing LMT... (293/503)
#   Skipped LMT: Volatility Not Cheap
#
# Processing L... (294/503)
#   Skipped L: Low Volume
#
# Processing LOW... (295/503)
#   Skipped LOW: No Reversal Signal
#
# Processing LULU... (296/503)
#   Skipped LULU: No Reversal Signal
#
# Processing LYB... (297/503)
#   Skipped LYB: Volatility Not Cheap
#
# Processing MTB... (298/503)
#   Skipped MTB: No Reversal Signal
#
# Processing MPC... (299/503)
#   Skipped MPC: Volatility Not Cheap
#
# Processing MKTX... (300/503)
#   Skipped MKTX: Low Volume
#
# Processing MAR... (301/503)
#   Skipped MAR: Volatility Not Cheap
#
# Processing MMC... (302/503)
#   Skipped MMC: Volatility Not Cheap
#
# Processing MLM... (303/503)
#   Skipped MLM: Low Volume
#
# Processing MAS... (304/503)
#   Skipped MAS: Volatility Not Cheap
#
# Processing MA... (305/503)
#   Skipped MA: Volatility Not Cheap
#
# Processing MTCH... (306/503)
#   Skipped MTCH: Volatility Not Cheap
#
# Processing MKC... (307/503)
#   Skipped MKC: No Reversal Signal
#
# Processing MCD... (308/503)
#   Skipped MCD: Volatility Not Cheap
#
# Processing MCK... (309/503)
#   Skipped MCK: Low Volume
#
# Processing MDT... (310/503)
#   Skipped MDT: Volatility Not Cheap
#
# Processing MRK... (311/503)
#   Skipped MRK: Volatility Not Cheap
#
# Processing META... (312/503)
#   Skipped META: Volatility Not Cheap
#
# Processing MET... (313/503)
#   Skipped MET: No Reversal Signal
#
# Processing MTD... (314/503)
#   Skipped MTD: Low Volume
#
# Processing MGM... (315/503)
#   Skipped MGM: Volatility Not Cheap
#
# Processing MCHP... (316/503)
#   Skipped MCHP: Volatility Not Cheap
#
# Processing MU... (317/503)
#   Skipped MU: No Reversal Signal
#
# Processing MSFT... (318/503)
#   Skipped MSFT: Volatility Not Cheap
#
# Processing MAA... (319/503)
#   Skipped MAA: Low Volume
#
# Processing MRNA... (320/503)
#   Skipped MRNA: Volatility Not Cheap
#
# Processing MHK... (321/503)
#   Skipped MHK: Low Volume
#
# Processing MOH... (322/503)
#   Skipped MOH: Low Volume
#
# Processing TAP... (323/503)
#   Skipped TAP: Volatility Not Cheap
#
# Processing MDLZ... (324/503)
#   Skipped MDLZ: Volatility Not Cheap
#
# Processing MPWR... (325/503)
#   Skipped MPWR: Low Volume
#
# Processing MNST... (326/503)
#   Skipped MNST: Volatility Not Cheap
#
# Processing MCO... (327/503)
#   Skipped MCO: Low Volume
#
# Processing MS... (328/503)
#   Skipped MS: No Reversal Signal
#
# Processing MOS... (329/503)
#   Skipped MOS: Volatility Not Cheap
#
# Processing MSI... (330/503)
#   Skipped MSI: Low Volume
#
# Processing MSCI... (331/503)
#   Skipped MSCI: Low Volume
#
# Processing NDAQ... (332/503)
#   Skipped NDAQ: Volatility Not Cheap
#
# Processing NTAP... (333/503)
#   Skipped NTAP: Volatility Not Cheap
#
# Processing NFLX... (334/503)
#   Skipped NFLX: Volatility Not Cheap
#
# Processing NEM... (335/503)
#   Skipped NEM: Volatility Not Cheap
#
# Processing NWSA... (336/503)
#   Skipped NWSA: Volatility Not Cheap
#
# Processing NWS... (337/503)
#   Skipped NWS: Low Volume
#
# Processing NEE... (338/503)
#   Skipped NEE: Volatility Not Cheap
#
# Processing NKE... (339/503)
#   Skipped NKE: No Reversal Signal
#
# Processing NI... (340/503)
#   Skipped NI: No Reversal Signal
#
# Processing NDSN... (341/503)
#   Skipped NDSN: Low Volume
#
# Processing NSC... (342/503)
#   Skipped NSC: Low Volume
#
# Processing NTRS... (343/503)
#   Skipped NTRS: Volatility Not Cheap
#
# Processing NOC... (344/503)
#   Skipped NOC: Low Volume
#
# Processing NCLH... (345/503)
#   Skipped NCLH: Volatility Not Cheap
#
# Processing NRG... (346/503)
#   Skipped NRG: No Reversal Signal
#
# Processing NUE... (347/503)
#   Skipped NUE: Volatility Not Cheap
#
# Processing NVDA... (348/503)
#   Skipped NVDA: No Reversal Signal
#
# Processing NVR... (349/503)
#   Skipped NVR: Low Volume
#
# Processing NXPI... (350/503)
#   >>> PASSED Filters: NXPI <<<
#       Score: 0.141 (Vol: 0.08, Signal: 0.20)
#       IV Pctile: 91.9%, IV/RV Ratio: 0.74
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 2.14%
#       Price: 168.37, Vol: 3557694
#
# Processing ORLY... (351/503)
#   Skipped ORLY: Low Volume
#
# Processing OXY... (352/503)
#   Skipped OXY: No Reversal Signal
#
# Processing ODFL... (353/503)
#   Skipped ODFL: Volatility Not Cheap
#
# Processing OMC... (354/503)
#   Skipped OMC: No Reversal Signal
#
# Processing ON... (355/503)
#   Skipped ON: Volatility Not Cheap
#
# Processing OKE... (356/503)
#   Skipped OKE: No Reversal Signal
#
# Processing ORCL... (357/503)
#   Skipped ORCL: No Reversal Signal
#
# Processing OTIS... (358/503)
#   Skipped OTIS: Volatility Not Cheap
#
# Processing PCAR... (359/503)
#   Skipped PCAR: Volatility Not Cheap
#
# Processing PKG... (360/503)
#   Skipped PKG: Low Volume
#
# Processing PLTR... (361/503)
#   Skipped PLTR: Volatility Not Cheap
#
# Processing PANW... (362/503)
#   Skipped PANW: Volatility Not Cheap
#
# Processing PARA... (363/503)
#   Skipped PARA: Volatility Not Cheap
#
# Processing PH... (364/503)
#   Skipped PH: Low Volume
#
# Processing PAYX... (365/503)
#   Skipped PAYX: No Reversal Signal
#
# Processing PAYC... (366/503)
#   Skipped PAYC: Low Volume
#
# Processing PYPL... (367/503)
#   Skipped PYPL: Volatility Not Cheap
#
# Processing PNR... (368/503)
#   Skipped PNR: Volatility Not Cheap
#
# Processing PEP... (369/503)
#   Skipped PEP: No Reversal Signal
#
# Processing PFE... (370/503)
#   Skipped PFE: Volatility Not Cheap
#
# Processing PCG... (371/503)
#   Skipped PCG: Volatility Not Cheap
#
# Processing PM... (372/503)
#   Skipped PM: Volatility Not Cheap
#
# Processing PSX... (373/503)
#   >>> PASSED Filters: PSX <<<
#       Score: 0.120 (Vol: 0.04, Signal: 0.20)
#       IV Pctile: 95.9%, IV/RV Ratio: 0.80
#       Signals (1): ['Stochastic_Oversold_Cross']
#       Exp. Move: 1.94%
#       Price: 99.28, Vol: 3598711
#
# Processing PNW... (374/503)
#   Skipped PNW: Low Volume
#
# Processing PNC... (375/503)
#   Skipped PNC: No Reversal Signal
#
# Processing POOL... (376/503)
#   Skipped POOL: Low Volume
#
# Processing PPG... (377/503)
#   Skipped PPG: Volatility Not Cheap
#
# Processing PPL... (378/503)
#   Skipped PPL: Volatility Not Cheap
#
# Processing PFG... (379/503)
#   Skipped PFG: Volatility Not Cheap
#
# Processing PG... (380/503)
#   Skipped PG: Volatility Not Cheap
#
# Processing PGR... (381/503)
#   Skipped PGR: No Reversal Signal
#
# Processing PLD... (382/503)
#   >>> PASSED Filters: PLD <<<
#       Score: 0.165 (Vol: 0.13, Signal: 0.20)
#       IV Pctile: 86.9%, IV/RV Ratio: 0.65
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 2.49%
#       Price: 102.75, Vol: 6141795
#
# Processing PRU... (383/503)
#   Skipped PRU: No Reversal Signal
#
# Processing PEG... (384/503)
#   Skipped PEG: Volatility Not Cheap
#
# Processing PTC... (385/503)
#   Skipped PTC: Low Volume
#
# Processing PSA... (386/503)
#   Skipped PSA: Low Volume
#
# Processing PHM... (387/503)
#   Skipped PHM: Volatility Not Cheap
#
# Processing PWR... (388/503)
#   Skipped PWR: Volatility Not Cheap
#
# Processing QCOM... (389/503)
#   Skipped QCOM: Volatility Not Cheap
#
# Processing DGX... (390/503)
#   Skipped DGX: Low Volume
#
# Processing RL... (391/503)
#   Skipped RL: Low Volume
#
# Processing RJF... (392/503)
#   Skipped RJF: Volatility Not Cheap
#
# Processing RTX... (393/503)
#   Skipped RTX: Volatility Not Cheap
#
# Processing O... (394/503)
#   Skipped O: No Reversal Signal
#
# Processing REG... (395/503)
#   Skipped REG: Low Volume
#
# Processing REGN... (396/503)
#   Skipped REGN: Low Volume
#
# Processing RF... (397/503)
#   Skipped RF: No Reversal Signal
#
# Processing RSG... (398/503)
#   Skipped RSG: Low Volume
#
# Processing RMD... (399/503)
#   Skipped RMD: Low Volume
#
# Processing RVTY... (400/503)
#   Skipped RVTY: Low Volume
#
# Processing ROK... (401/503)
#   Skipped ROK: Low Volume
#
# Processing ROL... (402/503)
#   Skipped ROL: Volatility Not Cheap
#
# Processing ROP... (403/503)
#   Skipped ROP: Low Volume
#
# Processing ROST... (404/503)
#   Skipped ROST: No Reversal Signal
#
# Processing RCL... (405/503)
#   Skipped RCL: No Reversal Signal
#
# Processing SPGI... (406/503)
#   Skipped SPGI: Low Volume
#
# Processing CRM... (407/503)
#   Skipped CRM: No Reversal Signal
#
# Processing SBAC... (408/503)
#   Skipped SBAC: Low Volume
#
# Processing SLB... (409/503)
#   Skipped SLB: No Reversal Signal
#
# Processing STX... (410/503)
#   Skipped STX: Volatility Not Cheap
#
# Processing SRE... (411/503)
#   Skipped SRE: Volatility Not Cheap
#
# Processing NOW... (412/503)
#   Skipped NOW: Volatility Not Cheap
#
# Processing SHW... (413/503)
#   Skipped SHW: Volatility Not Cheap
#
# Processing SPG... (414/503)
#   >>> PASSED Filters: SPG <<<
#       Score: 0.123 (Vol: 0.05, Signal: 0.20)
#       IV Pctile: 95.5%, IV/RV Ratio: 0.70
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 1.11%
#       Price: 151.10, Vol: 2050687
#
# Processing SWKS... (415/503)
#   Skipped SWKS: Volatility Not Cheap
#
# Processing SJM... (416/503)
#   Skipped SJM: Low Volume
#
# Processing SW... (417/503)
#   Skipped SW: Volatility Not Cheap
#
# Processing SNA... (418/503)
#   Skipped SNA: Low Volume
#
# Processing SOLV... (419/503)
#   Skipped SOLV: Low Volume
#
# Processing SO... (420/503)
#   Skipped SO: Volatility Not Cheap
#
# Processing LUV... (421/503)
#   Skipped LUV: No Reversal Signal
#
# Processing SWK... (422/503)
#   Skipped SWK: Volatility Not Cheap
#
# Processing SBUX... (423/503)
#   Skipped SBUX: Volatility Not Cheap
#
# Processing STT... (424/503)
#   >>> PASSED Filters: STT <<<
#       Score: 0.123 (Vol: 0.05, Signal: 0.20)
#       IV Pctile: 95.5%, IV/RV Ratio: 0.68
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 3.56%
#       Price: 81.36, Vol: 2284131
#
# Processing STLD... (425/503)
#   Skipped STLD: Volatility Not Cheap
#
# Processing STE... (426/503)
#   Skipped STE: Low Volume
#
# Processing SYK... (427/503)
#   Skipped SYK: Volatility Not Cheap
#
# Processing SMCI... (428/503)
#   Skipped SMCI: Volatility Not Cheap
#
# Processing SYF... (429/503)
#   Skipped SYF: No Reversal Signal
#
# Processing SNPS... (430/503)
#   Skipped SNPS: Low Volume
#
# Processing SYY... (431/503)
#   Skipped SYY: Volatility Not Cheap
#
# Processing TMUS... (432/503)
#   Skipped TMUS: Volatility Not Cheap
#
# Processing TROW... (433/503)
#   Skipped TROW: Volatility Not Cheap
#
# Processing TTWO... (434/503)
#   Skipped TTWO: Volatility Not Cheap
#
# Processing TPR... (435/503)
#   Skipped TPR: No Reversal Signal
#
# Processing TRGP... (436/503)
#   Skipped TRGP: No Reversal Signal
#
# Processing TGT... (437/503)
#   Skipped TGT: Volatility Not Cheap
#
# Processing TEL... (438/503)
#   Skipped TEL: Volatility Not Cheap
#
# Processing TDY... (439/503)
#   Skipped TDY: Low Volume
#
# Processing TER... (440/503)
#   Skipped TER: No Reversal Signal
#
# Processing TSLA... (441/503)
#   Skipped TSLA: No Reversal Signal
#
# Processing TXN... (442/503)
#   Skipped TXN: No Reversal Signal
#
# Processing TPL... (443/503)
#   Skipped TPL: Low Volume
#
# Processing TXT... (444/503)
#   Skipped TXT: Volatility Not Cheap
#
# Processing TMO... (445/503)
#   Skipped TMO: Volatility Not Cheap
#
# Processing TJX... (446/503)
#   Skipped TJX: No Reversal Signal
#
# Processing TKO... (447/503)
#   Skipped TKO: Volatility Not Cheap
#
# Processing TSCO... (448/503)
#   Skipped TSCO: Volatility Not Cheap
#
# Processing TT... (449/503)
#   Skipped TT: Volatility Not Cheap
#
# Processing TDG... (450/503)
#   Skipped TDG: Low Volume
#
# Processing TRV... (451/503)
#   Skipped TRV: No Reversal Signal
#
# Processing TRMB... (452/503)
#   Skipped TRMB: Volatility Not Cheap
#
# Processing TFC... (453/503)
#   Skipped TFC: No Reversal Signal
#
# Processing TYL... (454/503)
#   Skipped TYL: Low Volume
#
# Processing TSN... (455/503)
#   Skipped TSN: Volatility Not Cheap
#
# Processing USB... (456/503)
#   >>> PASSED Filters: USB <<<
#       Score: 0.120 (Vol: 0.04, Signal: 0.20)
#       IV Pctile: 95.9%, IV/RV Ratio: 0.76
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 1.52%
#       Price: 38.13, Vol: 15139880
#
# Processing UBER... (457/503)
#   Skipped UBER: Volatility Not Cheap
#
# Processing UDR... (458/503)
#   Skipped UDR: No Reversal Signal
#
# Processing ULTA... (459/503)
#   Skipped ULTA: Low Volume
#
# Processing UNP... (460/503)
#   Skipped UNP: Volatility Not Cheap
#
# Processing UAL... (461/503)
#   Skipped UAL: No Reversal Signal
#
# Processing UPS... (462/503)
#   Skipped UPS: Volatility Not Cheap
#
# Processing URI... (463/503)
#   Skipped URI: Low Volume
#
# Processing UNH... (464/503)
#   Skipped UNH: No Reversal Signal
#
# Processing UHS... (465/503)
#   Skipped UHS: Low Volume
#
# Processing VLO... (466/503)
#   Skipped VLO: No Reversal Signal
#
# Processing VTR... (467/503)
#   Skipped VTR: Volatility Not Cheap
#
# Processing VLTO... (468/503)
#   Skipped VLTO: Volatility Not Cheap
#
# Processing VRSN... (469/503)
#   Skipped VRSN: Low Volume
#
# Processing VRSK... (470/503)
#   Skipped VRSK: Low Volume
#
# Processing VZ... (471/503)
#   >>> PASSED Filters: VZ <<<
#       Score: 0.163 (Vol: 0.13, Signal: 0.20)
#       IV Pctile: 87.4%, IV/RV Ratio: 0.66
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 0.69%
#       Price: 44.33, Vol: 29175168
#
# Processing VRTX... (472/503)
#   Skipped VRTX: Volatility Not Cheap
#
# Processing VTRS... (473/503)
#   Skipped VTRS: Volatility Not Cheap
#
# Processing VICI... (474/503)
#   Skipped VICI: No Reversal Signal
#
# Processing V... (475/503)
#   Skipped V: No Reversal Signal
#
# Processing VST... (476/503)
#   Skipped VST: No Reversal Signal
#
# Processing VMC... (477/503)
#   Skipped VMC: Volatility Not Cheap
#
# Processing WRB... (478/503)
#   Skipped WRB: Volatility Not Cheap
#
# Processing GWW... (479/503)
#   Skipped GWW: Low Volume
#
# Processing WAB... (480/503)
#   Skipped WAB: Low Volume
#
# Processing WBA... (481/503)
#   Skipped WBA: No Reversal Signal
#
# Processing WMT... (482/503)
#   Skipped WMT: Volatility Not Cheap
#
# Processing DIS... (483/503)
#   Skipped DIS: Volatility Not Cheap
#
# Processing WBD... (484/503)
#   Skipped WBD: Volatility Not Cheap
#
# Processing WM... (485/503)
#   Skipped WM: Volatility Not Cheap
#
# Processing WAT... (486/503)
#   Skipped WAT: Low Volume
#
# Processing WEC... (487/503)
#   Skipped WEC: Volatility Not Cheap
#
# Processing WFC... (488/503)
#   Skipped WFC: No Reversal Signal
#
# Processing WELL... (489/503)
#   Skipped WELL: Volatility Not Cheap
#
# Processing WST... (490/503)
#   Skipped WST: Low Volume
#
# Processing WDC... (491/503)
#   Skipped WDC: Volatility Not Cheap
#
# Processing WY... (492/503)
#   Skipped WY: Volatility Not Cheap
#
# Processing WSM... (493/503)
#   Skipped WSM: No Reversal Signal
#
# Processing WMB... (494/503)
#   >>> PASSED Filters: WMB <<<
#       Score: 0.147 (Vol: 0.09, Signal: 0.20)
#       IV Pctile: 90.5%, IV/RV Ratio: 0.74
#       Signals (1): ['MACD_Histogram_Flip']
#       Exp. Move: 2.35%
#       Price: 59.45, Vol: 8119091
#
# Processing WTW... (495/503)
#   Skipped WTW: Low Volume
#
# Processing WDAY... (496/503)
#   Skipped WDAY: Volatility Not Cheap
#
# Processing WYNN... (497/503)
#   Skipped WYNN: Volatility Not Cheap
#
# Processing XEL... (498/503)
#   Skipped XEL: Volatility Not Cheap
#
# Processing XYL... (499/503)
#   Skipped XYL: Volatility Not Cheap
#
# Processing YUM... (500/503)
#   Skipped YUM: Volatility Not Cheap
#
# Processing ZBRA... (501/503)
#   Skipped ZBRA: Low Volume
#
# Processing ZBH... (502/503)
#   Skipped ZBH: Volatility Not Cheap
#
# Processing ZTS... (503/503)
#   Skipped ZTS: Volatility Not Cheap
#
#
# ==================================================
# Final Screening Results:
# ==================================================
#
# --- 24 Tickers Passed Filters (Ranked by Score) ---
# 1. ADBE
#    Score: 0.361 (Vol: 0.52, Signal: 0.20)
#    IV Pct (proxy): 47.7%, IV/RV Ratio: 0.63
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 0.94%
#    Price: 349.44, Avg Vol: 4819225
# --------------------
# 2. LLY
#    Score: 0.260 (Vol: 0.32, Signal: 0.20)
#    IV Pct (proxy): 68.0%, IV/RV Ratio: 0.64
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 0.95%
#    Price: 839.11, Avg Vol: 3781721
# --------------------
# 3. HPQ
#    Score: 0.258 (Vol: 0.32, Signal: 0.20)
#    IV Pct (proxy): 68.5%, IV/RV Ratio: 0.66
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 1.62%
#    Price: 23.71, Avg Vol: 10266530
# --------------------
# 4. DLTR
#    Score: 0.244 (Vol: 0.29, Signal: 0.20)
#    IV Pct (proxy): 71.2%, IV/RV Ratio: 0.60
#    Signals (1): ['SMA_Bullish_Cross']
#    Exp. Move: 1.48%
#    Price: 77.91, Avg Vol: 6718931
# --------------------
# 5. C
#    Score: 0.199 (Vol: 0.20, Signal: 0.20)
#    IV Pct (proxy): 80.2%, IV/RV Ratio: 0.60
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 0.98%
#    Price: 62.88, Avg Vol: 20559104
# --------------------
# 6. BAC
#    Score: 0.195 (Vol: 0.19, Signal: 0.20)
#    IV Pct (proxy): 81.1%, IV/RV Ratio: 0.56
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 0.92%
#    Price: 37.51, Avg Vol: 57066426
# --------------------
# 7. JNJ
#    Score: 0.192 (Vol: 0.18, Signal: 0.20)
#    IV Pct (proxy): 81.5%, IV/RV Ratio: 0.57
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 0.55%
#    Price: 158.09, Avg Vol: 10622624
# --------------------
# 8. KEY
#    Score: 0.192 (Vol: 0.18, Signal: 0.20)
#    IV Pct (proxy): 81.5%, IV/RV Ratio: 0.70
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 1.29%
#    Price: 14.40, Avg Vol: 18250440
# --------------------
# 9. ED
#    Score: 0.179 (Vol: 0.16, Signal: 0.20)
#    IV Pct (proxy): 84.2%, IV/RV Ratio: 0.78
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 2.68%
#    Price: 113.04, Avg Vol: 2949530
# --------------------
# 10. COF
#    Score: 0.174 (Vol: 0.15, Signal: 0.20)
#    IV Pct (proxy): 85.1%, IV/RV Ratio: 0.70
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 1.44%
#    Price: 162.64, Avg Vol: 5542021
# --------------------
# 11. PLD
#    Score: 0.165 (Vol: 0.13, Signal: 0.20)
#    IV Pct (proxy): 86.9%, IV/RV Ratio: 0.65
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 2.49%
#    Price: 102.75, Avg Vol: 6141795
# --------------------
# 12. VZ
#    Score: 0.163 (Vol: 0.13, Signal: 0.20)
#    IV Pct (proxy): 87.4%, IV/RV Ratio: 0.66
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 0.69%
#    Price: 44.33, Avg Vol: 29175168
# --------------------
# 13. WMB
#    Score: 0.147 (Vol: 0.09, Signal: 0.20)
#    IV Pct (proxy): 90.5%, IV/RV Ratio: 0.74
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 2.35%
#    Price: 59.45, Avg Vol: 8119091
# --------------------
# 14. NXPI
#    Score: 0.141 (Vol: 0.08, Signal: 0.20)
#    IV Pct (proxy): 91.9%, IV/RV Ratio: 0.74
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 2.14%
#    Price: 168.37, Avg Vol: 3557694
# --------------------
# 15. KMI
#    Score: 0.136 (Vol: 0.07, Signal: 0.20)
#    IV Pct (proxy): 92.8%, IV/RV Ratio: 0.75
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 1.38%
#    Price: 27.44, Avg Vol: 13557177
# --------------------
# 16. BSX
#    Score: 0.123 (Vol: 0.05, Signal: 0.20)
#    IV Pct (proxy): 95.5%, IV/RV Ratio: 0.75
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 1.43%
#    Price: 95.46, Avg Vol: 9491612
# --------------------
# 17. EMR
#    Score: 0.123 (Vol: 0.05, Signal: 0.20)
#    IV Pct (proxy): 95.5%, IV/RV Ratio: 0.78
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 2.37%
#    Price: 100.17, Avg Vol: 3542193
# --------------------
# 18. EQT
#    Score: 0.123 (Vol: 0.05, Signal: 0.20)
#    IV Pct (proxy): 95.5%, IV/RV Ratio: 0.79
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 2.1%
#    Price: 51.46, Avg Vol: 8299806
# --------------------
# 19. HBAN
#    Score: 0.123 (Vol: 0.05, Signal: 0.20)
#    IV Pct (proxy): 95.5%, IV/RV Ratio: 0.67
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 2.47%
#    Price: 13.77, Avg Vol: 25465979
# --------------------
# 20. SPG
#    Score: 0.123 (Vol: 0.05, Signal: 0.20)
#    IV Pct (proxy): 95.5%, IV/RV Ratio: 0.70
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 1.11%
#    Price: 151.10, Avg Vol: 2050687
# --------------------
# 21. STT
#    Score: 0.123 (Vol: 0.05, Signal: 0.20)
#    IV Pct (proxy): 95.5%, IV/RV Ratio: 0.68
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 3.56%
#    Price: 81.36, Avg Vol: 2284131
# --------------------
# 22. HES
#    Score: 0.120 (Vol: 0.04, Signal: 0.20)
#    IV Pct (proxy): 95.9%, IV/RV Ratio: 0.79
#    Signals (1): ['Stochastic_Oversold_Cross']
#    Exp. Move: 4.38%
#    Price: 131.94, Avg Vol: 2180681
# --------------------
# 23. PSX
#    Score: 0.120 (Vol: 0.04, Signal: 0.20)
#    IV Pct (proxy): 95.9%, IV/RV Ratio: 0.80
#    Signals (1): ['Stochastic_Oversold_Cross']
#    Exp. Move: 1.94%
#    Price: 99.28, Avg Vol: 3598711
# --------------------
# 24. USB
#    Score: 0.120 (Vol: 0.04, Signal: 0.20)
#    IV Pct (proxy): 95.9%, IV/RV Ratio: 0.76
#    Signals (1): ['MACD_Histogram_Flip']
#    Exp. Move: 1.52%
#    Price: 38.13, Avg Vol: 15139880
# --------------------
#
# --- 479 Tickers Failed Filters ---
# Failure Reasons:
#   - Volatility Not Cheap: 249
#   - No Reversal Signal: 117
#   - Low Volume: 113
#
# ==================================================
# Screening Complete.
# ==================================================
